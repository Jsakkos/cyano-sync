# %%
# %matplotlib inline
#%matplotlib notebook

# %%
import cytoflow as flow
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib
matplotlib.rc('figure', dpi = 160)

# %% [markdown]
# # Import samples and specify experimental condtions

# %%
inputs = [
    #["Experiment_Tube_001_001.fcs",0],
    ["Experiment_Tube_002_002.fcs",50],
    ["Experiment_Tube_003_003.fcs",25],
    ["Experiment_Tube_004_004.fcs",100],


 
]

       
tubes = []
for filename, pct in inputs:
    tubes.append(flow.Tube(file = 'data/' + filename, conditions = {'PCT' : pct}))
    
ex = flow.ImportOp(conditions = {'PCT' : 'int'},
                   tubes = tubes).apply()

# %%
flow.set_default_scale("log")

# %% [markdown]
# # Plot FITC-A histograms for all IPTG and AHL induction conditions

# %%
flow.HistogramView(channel = "FITC-A",
                   xfacet = "PCT").plot(ex)
# Out:
# C:\Users\Jonathan\anaconda3\envs\cytoflow\lib\site-packages\cytoflow\utility\log_scale.py:117: RuntimeWarning: invalid value encountered in log10

# %%
flow.DensityView(xchannel = "FSC-A", 
                 ychannel = "SSC-A",
                 xscale = 'log',
                 yscale = 'log').plot(ex, min_quantile = 0.005)

# %% [markdown]
# # Singlet gating to remove doublets

# %%
#channels = ['FSC-A','FSC-W','FSC-H','SSC-A','SSC-W','SSC-H']
#perm = combinations(channels,2)
FSC = [('FSC-A','FSC-W'),('FSC-A','FSC-H'),('FSC-W','FSC-H')]

#f, axes = plt.subplots(ncols=4,nrows=4)
#axs = axes.ravel()
for i,(x,y) in enumerate(FSC):  
    flow.DensityView(xchannel = x, 
                ychannel = y,
                xscale = 'log',
                yscale = 'log').plot(ex, min_quantile = 0.005)

# %%
SSC = [('SSC-A','SSC-W'),('SSC-A','SSC-H'),('SSC-W','SSC-H')]
for i,(x,y) in enumerate(SSC):  
    flow.DensityView(xchannel = x, 
                ychannel = y,
                xscale = 'linear',
                yscale = 'linear').plot(ex, min_quantile = 0.005)

# %% [markdown]
# ## Create and store singlet gate

# %%
r = flow.Range2DOp(name = "Range2D",
                   xchannel = "SSC-W",
                   xlow = 55000,
                   xhigh = 75000,
                   ychannel = "SSC-H",
                   ylow = 5000,
                   yhigh = 250000)
                   
rv = r.default_view(xscale ='linear',yscale='linear')

rv.plot(ex)
ex2 = r.apply(ex)

# %% [markdown]
# ## Use a gaussian mixture model to further gate the population

# %%
gm = flow.GaussianMixtureOp(name = "GM",
                            channels = ['FSC-A', 'SSC-A'],
                            scale = {'FSC-A' : 'log',
                                     'SSC-A' : 'linear'},
                            num_components = 1,
                            sigma = 2)
gm.estimate(ex2)
ex_gm = gm.apply(ex2)
gm.default_view().plot(ex_gm, alpha = 0.02)
# Out:
# C:\Users\Jonathan\anaconda3\envs\cytoflow\lib\site-packages\cytoflow\operations\base_op_views.py:342: CytoflowViewWarning: Setting 'huefacet' to 'GM_1'

# %%
gm3 = flow.GaussianMixtureOp(name = "GM3",
                            channels = ['FSC-A', 'Pacific Blue-A'],
                            scale = {'FSC-A' : 'log',
                                     'Pacific Blue-A' : 'log'},
                            num_components = 1,
                            sigma = 2)
gm3.estimate(ex_gm)
ex_gm2 = gm3.apply(ex_gm)
gm3.default_view().plot(ex_gm2, alpha = 0.02)
# Out:
# C:\Users\Jonathan\anaconda3\envs\cytoflow\lib\site-packages\cytoflow\utility\log_scale.py:117: RuntimeWarning: invalid value encountered in log10
# C:\Users\Jonathan\anaconda3\envs\cytoflow\lib\site-packages\cytoflow\utility\log_scale.py:117: RuntimeWarning: invalid value encountered in log10
# C:\Users\Jonathan\anaconda3\envs\cytoflow\lib\site-packages\cytoflow\operations\gaussian.py:529: RuntimeWarning: invalid value encountered in less_equal
# C:\Users\Jonathan\anaconda3\envs\cytoflow\lib\site-packages\cytoflow\operations\base_op_views.py:342: CytoflowViewWarning: Setting 'huefacet' to 'GM3_1'

# %%
df =ex_gm2.data

# %% [markdown]
# # filter out events that don't fall within the gates

# %%
df = df[(df.GM_1==True) & (df.GM3_1==True) & (df.Range2D==True) & (df['FITC-A'] >0)]
df
# Out:
#               FITC-A   FITC-H        FITC-W         FSC-A    FSC-H  \
# 0        3835.010010   3759.0  66861.187500   5473.780273   5739.0
# 1        3172.849854   3593.0  57872.503906   5732.040039   5941.0
# 2        3021.550049   3248.0  60966.843750   5758.680176   5972.0
# 3        3669.469971   4067.0  59130.164062   5682.459961   5847.0
# 4        3089.189941   3464.0  58444.906250   5168.899902   5372.0
# 5        3054.479980   3456.0  57921.988281   5082.319824   5140.0
# 6        2726.959961   2908.0  61456.003906   5170.379883   5384.0
# 7        2277.510010   2353.0  63433.445312   5478.959961   5749.0
# 8        3238.709961   3680.0  57677.199219   5980.680176   6244.0
# 9        1439.130005   1606.0  58726.542969   5053.459961   5346.0
# 10       2858.679932   3249.0  57662.800781   5387.200195   5733.0
# 11       2478.649902   2745.0  59176.976562   5427.160156   5725.0
# 12       2419.909912   2701.0  58715.742188   4910.640137   5145.0
# 13       3919.560059   3836.0  66963.578125   6207.120117   6504.0
# 14       3050.030029   3001.0  66606.718750   5571.459961   5741.0
# 15       2881.820068   3261.0  57915.656250   5268.800293   5449.0
# 16       1982.919922   2308.0  56305.300781   5270.280273   5504.0
# 18       3050.919922   3446.0  58022.371094   5250.300293   5506.0
# 20       3633.869873   3706.0  64260.464844   5007.580078   5070.0
# 21       2901.399902   2816.0  67523.484375   5011.280273   5252.0
# 23       2679.790039   2893.0  60706.089844   5848.959961   6057.0
# 25       2795.489990   2997.0  61129.539062   5237.720215   5377.0
# 26       2793.709961   3401.0  53833.746094   6119.800293   6221.0
# 28       5421.879883   5321.0  66778.492188   5843.040039   5885.0
# 29       3592.929932   3796.0  62030.101562   5635.839844   5696.0
# 31       2652.199951   2777.0  62590.773438   6201.200195   6381.0
# 32       3234.260010   3377.0  62765.906250   5540.379883   5781.0
# 33       2655.760010   3024.0  57555.519531   6250.040039   6457.0
# 34       2561.419922   2741.0  61242.332031   4978.720215   5217.0
# 35       4240.850098   4220.0  65859.804688   5273.240234   5384.0
# ...              ...      ...           ...           ...      ...
# 299956  13091.009766  13176.0  65113.265625   8655.040039   8508.0
# 299957  10675.549805  10720.0  65264.257812   9030.959961   8788.0
# 299958   7301.560059   6608.0  72414.507812  10175.000000  10196.0
# 299960   8545.780273   8992.0  62283.839844   8021.600098   7977.0
# 299962   9268.459961   9213.0  65930.507812   9579.299805   9561.0
# 299963   5636.370117   5616.0  65773.710938   9417.980469   9412.0
# 299964   9102.919922   8688.0  68665.859375  10296.360352  10100.0
# 299965   8463.009766   8652.0  64104.464844  11210.259766  10904.0
# 299966   8894.660156   8909.0  65430.515625  10406.620117  10185.0
# 299968   4207.029785   4600.0  59937.375000   9286.259766   9388.0
# 299969   8742.469727   8517.0  67270.929688   7040.359863   6625.0
# 299970   8521.750000   8818.0  63334.250000   8537.379883   8358.0
# 299971  11435.609375  11013.0  68050.859375  10912.040039  10529.0
# 299973   8907.120117   8460.0  68999.648438  10802.520508  10648.0
# 299974   5016.929688   4902.0  67072.531250   8692.040039   8498.0
# 299975   7736.770020   7713.0  65737.968750   9036.139648   8805.0
# 299976   8107.009766   8210.0  64713.886719   9596.320312   9558.0
# 299981   7722.529785   7954.0  63628.828125   7304.540039   7302.0
# 299982   7656.669922   8344.0  60137.527344  10254.919922  10188.0
# 299983   9565.719727   9315.0  67299.945312  11378.240234  11111.0
# 299985   9012.139648   9351.0  63161.113281   9653.299805   9555.0
# 299986   7645.989746   7208.0  69518.250000   5521.140137   5196.0
# 299988   9318.299805   9620.0  63480.675781  12100.480469  11952.0
# 299990   9083.339844   9228.0  64508.644531   8409.360352   8168.0
# 299991   7521.389648   7669.0  64274.585938   7562.800293   7420.0
# 299992   9640.479492   9507.0  66456.132812   8538.860352   8455.0
# 299993   7114.659668   6889.0  67682.734375   7434.780273   7165.0
# 299996  10318.660156   9796.0  69032.632812  11211.740234  11120.0
# 299997    905.130005   1077.0  55077.621094   7576.120117   7432.0
# 299998   9440.229492   8929.0  69288.265625   9793.160156   9509.0
#
#                FSC-W  PCT  Pacific Blue-A  Pacific Blue-H  Pacific Blue-W  \
# 0       62507.347656   50      393.299988           657.0    39231.820312
# 1       63230.933594   50      511.750000           372.0    90156.039062
# 2       63195.058594   50     1582.400024          1599.0    64855.640625
# 3       63691.757812   50      721.049988           553.0    85451.593750
# 4       63058.273438   50     1052.250000           900.0    76622.507812
# 5       64800.566406   50      750.950012           713.0    69024.203125
# 6       62935.738281   50      358.799988           743.0    31647.800781
# 7       62457.664062   50      886.649963           780.0    74496.781250
# 8       62772.242188   50     1294.900024          1593.0    53272.171875
# 9       61949.785156   50      236.899994           825.0    18818.759766
# 10      61583.039062   50      650.899963           348.0   122578.679688
# 11      62126.531250   50      846.399963           709.0    78236.484375
# 12      62550.769531   50      855.599976           913.0    61415.773438
# 13      62544.562500   50      577.299988           608.0    62226.863281
# 14      63600.632812   50      506.000000           549.0    60402.945312
# 15      63368.707031   50      909.649963          1009.0    59083.070312
# 16      62753.105469   50      539.349976           992.0    35631.894531
# 18      62492.503906   50      322.000000           848.0    24885.132812
# 20      64729.144531   50      422.049988           628.0    44043.742188
# 21      62532.230469   50     1337.449951           765.0   114576.632812
# 23      63285.035156   50      316.250000           633.0    32742.117188
# 25      63838.429688   50     1296.049927          1281.0    66305.953125
# 26      64469.894531   50      686.549988           620.0    72570.546875
# 28      65068.726562   50      913.099976           845.0    70817.656250
# 29      64843.820312   50      741.750000           560.0    86805.945312
# 31      63689.371094   50      453.099976           549.0    54088.089844
# 32      62808.222656   50      163.300003           508.0    21066.986328
# 33      63435.433594   50      595.700012           652.0    59876.988281
# 34      62542.726562   50      614.099976           632.0    63679.835938
# 35      64187.792969   50      808.450012          1304.0    40630.812500
# ...              ...  ...             ...             ...             ...
# 299956  66668.625000  100     2117.149902          1852.0    74918.750000
# 299957  67347.875000  100     1382.299927          1483.0    61085.914062
# 299958  65401.023438  100     2285.050049          2801.0    53464.132812
# 299960  65902.429688  100     1282.250000           802.0   104779.976562
# 299962  65661.437500  100     1036.150024          1413.0    48057.417969
# 299963  65577.640625  100      553.149963          1369.0    26480.083984
# 299964  66810.132812  100      616.399963          1001.0    40356.035156
# 299965  67376.710938  100     2366.699951          2008.0    77243.054688
# 299966  66962.031250  100     2219.500000          2609.0    55752.070312
# 299968  64825.777344  100      859.049988          1184.0    47549.578125
# 299969  69644.843750  100     2351.750000          2188.0    70440.718750
# 299970  66942.539062  100      538.200012           720.0    48988.160156
# 299971  67920.171875  100     2395.449951          2328.0    67434.804688
# 299973  66487.039062  100     1906.699951          2245.0    55660.347656
# 299974  67032.429688  100      447.349976           685.0    42799.316406
# 299975  67256.390625  100     1036.150024          1480.0    45881.843750
# 299976  65798.750000  100     1610.000000          1232.0    85643.632812
# 299981  65558.796875  100      379.500000           923.0    26945.734375
# 299982  65966.476562  100     1753.750000           900.0   127704.179688
# 299983  67112.257812  100      943.000000          1484.0    41644.507812
# 299985  66210.226562  100     2045.849976          1961.0    68371.656250
# 299986  69636.921875  100     2078.050049          2020.0    67419.359375
# 299988  66350.156250  100     2921.000000          2589.0    73939.992188
# 299990  67472.554688  100      623.299988           816.0    50059.546875
# 299991  66797.273438  100     1238.549927          1165.0    69673.476562
# 299992  66186.007812  100     1154.599976          1450.0    52184.738281
# 299993  68003.593750  100      884.349976          1228.0    47196.062500
# 299996  66076.671875  100     1780.199951          2068.0    56415.468750
# 299997  66806.867188  100     1347.799927          1541.0    57319.542969
# 299998  67494.437500  100     2003.299927          1954.0    67189.492188
#
#         PerCP-Cy5-5-A  PerCP-Cy5-5-H          SSC-A     SSC-H         SSC-W  \
# 0         6854.779785         7585.0   47113.039062   50863.0  60704.250000
# 1         8040.259766         7822.0   58772.039062   61958.0  62166.058594
# 2        11245.149414        10891.0   66355.726562   69376.0  62682.902344
# 3         9061.089844         8953.0   63800.539062   67111.0  62303.230469
# 4         8044.709961         8192.0   51421.527344   53596.0  62877.105469
# 5        11331.479492        11785.0   43351.898438   46852.0  60640.101562
# 6         9278.250000         9367.0   19260.490234   21772.0  57976.089844
# 7        11566.439453        11884.0   49047.007812   52881.0  60784.488281
# 8        10346.250000        10105.0   63813.890625   67300.0  62141.265625
# 9         9165.219727         9965.0   51410.847656   55270.0  60960.039062
# 10        8537.769531         8696.0   42326.621094   45221.0  61341.355469
# 11        8114.129883         9105.0   17087.109375   20189.0  55466.878906
# 12       11440.059570        12049.0   59634.449219   63021.0  62014.300781
# 13        8396.259766         8740.0   50524.410156   54472.0  60786.601562
# 14        8305.479492         8561.0   58621.628906   62141.0  61824.351562
# 15        9690.320312         9121.0   49484.000000   53485.0  60633.511719
# 16        8953.399414         9120.0   45949.808594   49636.0  60669.003906
# 18        6472.969727         7120.0   55488.828125   59542.0  61074.804688
# 20       14932.419922        14576.0   39435.898438   42846.0  60320.003906
# 21        8847.490234         8521.0   41693.828125   44928.0  60818.347656
# 23       11472.099609        11085.0   52787.679688   56729.0  60982.800781
# 25       12144.049805        12613.0   63430.300781   65809.0  63167.167969
# 26       12953.950195        12668.0   52824.167969   55417.0  62469.726562
# 28       13333.979492        13673.0   74697.695312   77229.0  63387.949219
# 29        6962.469727         7444.0   46081.527344   48688.0  62027.582031
# 31       11521.939453        11877.0   21482.820312   24745.0  56896.269531
# 32        7293.549805         7592.0   23892.939453   27541.0  56855.148438
# 33       10406.769531        11287.0   68630.570312   71930.0  62529.859375
# 34        8535.099609         9224.0   27088.929688   30133.0  58915.476562
# 35       16122.349609        16168.0   64097.800781   66956.0  62738.421875
# ...               ...            ...            ...       ...           ...
# 299956   11476.549805        10920.0   88061.046875   87736.0  65778.804688
# 299957   12055.049805        11931.0   91091.500000   89728.0  66531.875000
# 299958   13388.269531        13045.0   78767.671875   79380.0  65030.468750
# 299960    6292.299805         6593.0   75079.507812   74138.0  66368.265625
# 299962    9531.009766         9605.0   75682.929688   76265.0  65035.816406
# 299963    6836.979980         6525.0   64638.027344   64836.0  65335.890625
# 299964    9034.389648         9737.0   75008.312500   75088.0  65466.453125
# 299965   13694.429688        12876.0  115695.546875  108380.0  69959.617188
# 299966   13565.379883        12597.0   81425.210938   81101.0  65797.984375
# 299968   12019.450195        11536.0   46972.417969   47980.0  64159.746094
# 299969   16263.859375        15708.0  108538.171875  106657.0  66691.898438
# 299970   10650.629883        10448.0   79111.210938   79174.0  65484.031250
# 299971   15189.629883        14476.0   96389.671875   93781.0  67358.992188
# 299973    9752.620117         9045.0   86533.812500   86396.0  65640.539062
# 299974    9686.759766         9721.0   41972.398438   44050.0  62445.023438
# 299975    9776.649414         9928.0   74708.375000   75685.0  64690.335938
# 299976    8272.549805         8080.0   71580.921875   71734.0  65396.148438
# 299981    7282.870117         6747.0   61855.890625   62130.0  65246.859375
# 299982   13592.080078        12224.0   93321.835938   94232.0  64903.003906
# 299983   13651.709961        13768.0   82268.929688   81671.0  66015.804688
# 299985    7549.870117         6809.0   80973.976562   80823.0  65658.429688
# 299986   11289.649414        10688.0   99823.289062  100136.0  65331.343750
# 299988   11072.490234        10697.0   98476.718750   98560.0  65480.625000
# 299990   11547.750000        10244.0   75173.851562   76060.0  64772.460938
# 299991    8761.160156         8854.0   41601.269531   43119.0  63229.222656
# 299992   11802.290039        11930.0   52302.628906   53911.0  63580.808594
# 299993   15176.279297        14488.0   69161.898438   69257.0  65446.003906
# 299996   11418.700195        11380.0   90885.015625   90736.0  65643.632812
# 299997    6004.830078         5522.0   37113.000000   37167.0  65440.785156
# 299998    9437.559570         8914.0   98692.992188   97365.0  66429.867188
#
#                Time  Range2D  GM_1  GM3_1
# 0         43.299999     True  True   True
# 1         43.400002     True  True   True
# 2         43.400002     True  True   True
# 3         43.400002     True  True   True
# 4         43.400002     True  True   True
# 5         43.400002     True  True   True
# 6         43.400002     True  True   True
# 7         43.400002     True  True   True
# 8         43.500000     True  True   True
# 9         43.500000     True  True   True
# 10        43.500000     True  True   True
# 11        43.500000     True  True   True
# 12        43.500000     True  True   True
# 13        43.599998     True  True   True
# 14        43.599998     True  True   True
# 15        43.599998     True  True   True
# 16        43.599998     True  True   True
# 18        43.700001     True  True   True
# 20        43.700001     True  True   True
# 21        43.700001     True  True   True
# 23        43.700001     True  True   True
# 25        43.799999     True  True   True
# 26        43.799999     True  True   True
# 28        43.799999     True  True   True
# 29        43.799999     True  True   True
# 31        43.799999     True  True   True
# 32        43.799999     True  True   True
# 33        43.900002     True  True   True
# 34        43.900002     True  True   True
# 35        43.900002     True  True   True
# ...             ...      ...   ...    ...
# 299956  2144.000000     True  True   True
# 299957  2144.100098     True  True   True
# 299958  2144.100098     True  True   True
# 299960  2144.100098     True  True   True
# 299962  2144.100098     True  True   True
# 299963  2144.100098     True  True   True
# 299964  2144.199951     True  True   True
# 299965  2144.199951     True  True   True
# 299966  2144.199951     True  True   True
# 299968  2144.300049     True  True   True
# 299969  2144.300049     True  True   True
# 299970  2144.300049     True  True   True
# 299971  2144.300049     True  True   True
# 299973  2144.300049     True  True   True
# 299974  2144.399902     True  True   True
# 299975  2144.399902     True  True   True
# 299976  2144.500000     True  True   True
# 299981  2144.600098     True  True   True
# 299982  2144.600098     True  True   True
# 299983  2144.600098     True  True   True
# 299985  2144.600098     True  True   True
# 299986  2144.600098     True  True   True
# 299988  2144.699951     True  True   True
# 299990  2144.699951     True  True   True
# 299991  2144.800049     True  True   True
# 299992  2144.899902     True  True   True
# 299993  2144.899902     True  True   True
# 299996  2144.899902     True  True   True
# 299997  2145.000000     True  True   True
# 299998  2145.000000     True  True   True
#
# [231908 rows x 19 columns]

# %%
data = df[['FITC-A','PCT']]
mfi = data.groupby(['PCT'])['FITC-A'].median().reset_index()

# %%
# Add first tube back to dataset

# %%
inputs = [
    ["Experiment_Tube_001_001.fcs",0],
 
]

       
tubes = []
for filename, pct in inputs:
    tubes.append(flow.Tube(file = 'data/' + filename, conditions = {'PCT' : pct}))
    
ex = flow.ImportOp(conditions = {'PCT' : 'int'},
                   tubes = tubes).apply()
       

       
r = flow.Range2DOp(name = "Range2D",
                   xchannel = "SSC-W",
                   xlow = 55000,
                   xhigh = 75000,
                   ychannel = "SSC-H",
                   ylow = 5000,
                   yhigh = 250000)
                   
rv = r.default_view(xscale ='linear',yscale='linear')

rv.plot(ex)
ex2 = r.apply(ex)
gm = flow.GaussianMixtureOp(name = "GM",
                            channels = ['FSC-A', 'SSC-A'],
                            scale = {'FSC-A' : 'log',
                                     'SSC-A' : 'linear'},
                            num_components = 1,
                            sigma = 2)
gm.estimate(ex2)
ex_gm = gm.apply(ex2)
gm.default_view().plot(ex_gm, alpha = 0.02)
gm3 = flow.GaussianMixtureOp(name = "GM3",
                            channels = ['FSC-A', 'Pacific Blue-A'],
                            scale = {'FSC-A' : 'log',
                                     'Pacific Blue-A' : 'log'},
                            num_components = 1,
                            sigma = 2)
gm3.estimate(ex_gm)
ex_gm2 = gm3.apply(ex_gm)
df2 =ex_gm2.data
df2 = df2[(df.GM_1==True) & (df2.GM3_1==True) & (df2.Range2D==True) & (df2['FITC-A'] >0)]
mfi = mfi.append(df2.groupby(['PCT'])['FITC-A'].median().reset_index(),ignore_index=True)
# Out:
# C:\Users\Jonathan\anaconda3\envs\cytoflow\lib\site-packages\cytoflow\operations\base_op_views.py:342: CytoflowViewWarning: Setting 'huefacet' to 'GM_1'
# C:\Users\Jonathan\anaconda3\envs\cytoflow\lib\site-packages\cytoflow\utility\log_scale.py:117: RuntimeWarning: invalid value encountered in log10
# C:\Users\Jonathan\anaconda3\envs\cytoflow\lib\site-packages\cytoflow\utility\log_scale.py:117: RuntimeWarning: invalid value encountered in log10
# C:\Users\Jonathan\anaconda3\envs\cytoflow\lib\site-packages\cytoflow\operations\gaussian.py:529: RuntimeWarning: invalid value encountered in less_equal
# C:\Users\Jonathan\anaconda3\envs\cytoflow\lib\site-packages\ipykernel_launcher.py:46: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# # Percent supernatant from E. coli vs mNG intensity

# %%
sns.set_context('talk')
sns.set_style('white')
f, ax = plt.subplots(figsize=(8,6))
sns.pointplot(x='PCT',y='FITC-A',data=mfi)

f.savefig('Lux-ec-se.png',dpi=600)

# %% [markdown]
# # Percent supernatant from E. coli vs mNG intensity

# %%
data =df.append(df2,ignore_index=True)
