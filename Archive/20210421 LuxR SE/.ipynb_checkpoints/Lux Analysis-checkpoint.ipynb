# %%
# %matplotlib inline
#%matplotlib notebook

# %%
import cytoflow as flow
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib
import scipy.stats as stats
import scipy as sp
from scipy.stats.mstats import gmean
import scipy.optimize as opt
import numpy as np
from numpy import median
matplotlib.rc('figure', dpi = 160)

# %% [markdown]
# # Import samples and specify experimental condtions

# %% [markdown]
# sets the conditions of the tube

# %%
inputs = [
    ["20210420_Tube_001_001.fcs",0,0,'WT'],
    ["20210420_Tube_002_002.fcs",0,0,'LuxR'],
    ["20210420_Tube_003_003.fcs",0.5e-6,0,'LuxR'],
    ["20210420_Tube_004_004.fcs",0.5e-7,0,'LuxR'],
    ["20210420_Tube_005_005.fcs",0.5e-8,0,'LuxR'],
    ["20210420_Tube_006_006.fcs",0.5e-9,0,'LuxR'],
    ["20210420_Tube_007_007.fcs",0.5e-10,0,'LuxR'],
    ["20210420_Tube_008_008.fcs",0,0.05,'LuxR'],
    ["20210420_Tube_009_009.fcs",0.5e-6,0.05,'LuxR'],
    ["20210420_Tube_010_010.fcs",0.5e-7,0.05,'LuxR'],
    ["20210420_Tube_011_011.fcs",0.5e-8,0.05,'LuxR'],
    ["20210420_Tube_012_012.fcs",0.5e-9,0.05,'LuxR'],
    ["20210420_Tube_013_013.fcs",0.5e-10,0.05,'LuxR'],
    ["20210420_Tube_014_014.fcs",0,0.25,'LuxR'],
    ["20210420_Tube_015_015.fcs",0.5e-6,0.25,'LuxR'],
    ["20210420_Tube_016_016.fcs",0.5e-7,0.25,'LuxR'],
    ["20210420_Tube_017_017.fcs",0.5e-8,0.25,'LuxR'],
    ["20210420_Tube_018_018.fcs",0.5e-9,0.25,'LuxR'],
    ["20210420_Tube_019_019.fcs",0.5e-10,0.25,'LuxR'],
    ["20210420_Tube_020_020.fcs",0,0.5,'LuxR'],
    ["20210420_Tube_021_021.fcs",0.5e-6,0.5,'LuxR'],
    ["20210420_Tube_022_022.fcs",0.5e-7,0.5,'LuxR'],
    ["20210420_Tube_023_023.fcs",0.5e-8,0.5,'LuxR'],
    ["20210420_Tube_024_024.fcs",0.5e-9,0.5,'LuxR'],
    ["20210420_Tube_025_025.fcs",0.5e-10,0.5,'LuxR']
]

       
tubes = []
for filename, ahl, iptg, family in inputs:
    tubes.append(flow.Tube(file = 'data/' + filename, conditions = {'AHL' : ahl, 'IPTG' : iptg, 'Family' : family}))
    
ex = flow.ImportOp(conditions = {'AHL' : 'float', 'IPTG' : 'float', 'Family' : 'str'},
                   tubes = tubes).apply()

# %%
flow.set_default_scale("log")

# %% [markdown]
# # Plot FITC-A histograms for all IPTG and AHL induction conditions

# %%
flow.HistogramView(channel = "FITC-A",
                   xfacet = "AHL",
                  yfacet = 'IPTG').plot(ex)

# %%
flow.DensityView(xchannel = "FSC-A", 
                 ychannel = "SSC-A",
                 xscale = 'log',
                 yscale = 'log').plot(ex, min_quantile = 0.005)

# %% [markdown]
# # Singlet gating to remove doublets

# %%
#channels = ['FSC-A','FSC-W','FSC-H','SSC-A','SSC-W','SSC-H']
#perm = combinations(channels,2)
FSC = [('FSC-A','FSC-W'),('FSC-A','FSC-H'),('FSC-W','FSC-H')]

#f, axes = plt.subplots(ncols=4,nrows=4)
#axs = axes.ravel()
for i,(x,y) in enumerate(FSC):  
    flow.DensityView(xchannel = x, 
                ychannel = y,
                xscale = 'log',
                yscale = 'log').plot(ex, min_quantile = 0.005)

# %%
SSC = [('SSC-A','SSC-W'),('SSC-A','SSC-H'),('SSC-W','SSC-H')]
for i,(x,y) in enumerate(SSC):  
    flow.DensityView(xchannel = x, 
                ychannel = y,
                xscale = 'linear',
                yscale = 'linear').plot(ex, min_quantile = 0.005)

# %% [markdown]
# ## Create and store singlet gate

# %% [markdown]
# saves the single data as ex2

# %%
r = flow.Range2DOp(name = "Range2D",
                   xchannel = "SSC-W",
                   xlow = 55000,
                   xhigh = 80000,
                   ychannel = "SSC-H",
                   ylow = 1000,
                   yhigh = 10000)
                   
rv = r.default_view(xscale ='log',yscale='log')

rv.plot(ex)
ex2 = r.apply(ex)

# %% [markdown]
# ## Use a gaussian mixture model to further gate the population

# %%
gm = flow.GaussianMixtureOp(name = "GM",
                            channels = ['FSC-A', 'SSC-A'],
                            scale = {'FSC-A' : 'log',
                                     'SSC-A' : 'log'},
                            num_components = 1,
                            sigma = 2)
gm.estimate(ex2)
ex_gm = gm.apply(ex2)
gm.default_view().plot(ex_gm, alpha = 0.02)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/cytoflow/operations/base_op_views.py:341: CytoflowViewWarning: Setting 'huefacet' to 'GM_1'

# %%
gm3 = flow.GaussianMixtureOp(name = "GM3",
                            channels = ['FSC-A', 'Pacific Blue-A'],
                            scale = {'FSC-A' : 'log',
                                     'Pacific Blue-A' : 'log'},
                            num_components = 1,
                            sigma = 2)
gm3.estimate(ex_gm)
ex_gm2 = gm3.apply(ex_gm)
gm3.default_view().plot(ex_gm2, alpha = 0.02)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/cytoflow/operations/base_op_views.py:341: CytoflowViewWarning: Setting 'huefacet' to 'GM3_1'

# %%
df =ex_gm2.data

# %% [markdown]
# take the stuff from cytoflow and changing it to datatframe

# %% [markdown]
# # filter out events that don't fall within the gates

# %%
df = df[(df.GM_1==True) & (df.GM3_1==True) & (df.Range2D==True) & (df['FITC-A'] >0)]
df
# Out:
#                  AHL     AmCyan-A  AmCyan-H       AmCyan-W       FITC-A  \
# 3       0.000000e+00  5693.160156    4653.0   80186.320312   172.479996
# 4       0.000000e+00   506.160004     374.0   88694.390625   123.199997
# 8       0.000000e+00   346.559998     237.0   95831.882812    66.879997
# 9       0.000000e+00  9817.679688    5142.0  125128.632812    75.680000
# 10      0.000000e+00  3527.159912    3148.0   73429.453125   136.399994
# ...              ...          ...       ...            ...          ...
# 375224  5.000000e-11   147.059998     138.0   69838.578125  1411.520020
# 375226  5.000000e-11   188.099991     206.0   59841.367188  1620.079956
# 375227  5.000000e-11  1712.280029    1716.0   65393.929688  1078.880005
# 375234  5.000000e-11  2964.000000    2800.0   69374.539062  2547.600098
# 375236  5.000000e-11   790.020020     839.0   61710.082031  1267.199951
#
#         FITC-H         FITC-W         FSC-A    FSC-H         FSC-W  ...  \
# 3        283.0   39942.222656  16232.280273  15039.0  70736.000000  ...
# 4         64.0  126156.804688   8941.770508   8996.0  65140.941406  ...
# 8        107.0   40963.066406   9735.280273   9743.0  65484.074219  ...
# 9         76.0   65260.058594   8774.600586   8616.0  66742.367188  ...
# 10       152.0   58809.933594  20969.980469  18636.0  73743.757812  ...
# ...        ...            ...           ...      ...           ...  ...
# 375224  1369.0   67571.492188   8522.750000   8349.0  66899.859375  ...
# 375226  1503.0   70641.093750   8055.550293   8075.0  65378.148438  ...
# 375227  1121.0   63073.582031  14459.840820  14485.0  65422.171875  ...
# 375234  2593.0   64388.558594  24644.800781  24805.0  65112.746094  ...
# 375236  1199.0   69263.734375  10422.209961  10043.0  68010.546875  ...
#
#        Pacific Blue-A  Pacific Blue-H  Pacific Blue-W        SSC-A   SSC-H  \
# 3         2962.859863          2489.0    78012.851562  5482.399902  4891.0
# 4          558.599976           338.0   108308.898438  2677.840088  2704.0
# 8          484.500000           409.0    77633.718750  2018.719971  2027.0
# 9         5218.919922          2838.0   120516.960938  3613.280029  3048.0
# 10        1915.199951          1544.0    81291.804688  2894.320068  2632.0
# ...               ...             ...             ...          ...     ...
# 375224     184.679993            90.0   134479.875000  2560.800049  2605.0
# 375226     158.459991           126.0    82419.320312  2650.560059  2683.0
# 375227     973.559998           768.0    83077.117188  2332.879883  2369.0
# 375234    1374.839966          1344.0    67039.812500  3050.080078  3157.0
# 375236     433.199982           455.0    62396.031250  2631.199951  2667.0
#
#                SSC-W         Time  Range2D  GM_1  GM3_1
# 3       73460.343750    51.900002     True  True   True
# 4       64901.968750    52.000000     True  True   True
# 8       65268.300781    52.200001     True  True   True
# 9       77690.265625    52.200001     True  True   True
# 10      72067.695312    52.299999     True  True   True
# ...              ...          ...      ...   ...    ...
# 375224  64424.027344  1180.099976     True  True   True
# 375226  64743.609375  1180.199951     True  True   True
# 375227  64536.777344  1180.300049     True  True   True
# 375234  63316.457031  1180.900024     True  True   True
# 375236  64656.289062  1180.900024     True  True   True
#
# [271211 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['AHL', 'AmCyan-A', 'AmCyan-H', 'AmCyan-W', 'FITC-A', 'FITC-H', 'FITC-W',
#        'FSC-A', 'FSC-H', 'FSC-W', 'Family', 'IPTG', 'Pacific Blue-A',
#        'Pacific Blue-H', 'Pacific Blue-W', 'SSC-A', 'SSC-H', 'SSC-W', 'Time',
#        'Range2D', 'GM_1', 'GM3_1'],
#       dtype='object')

# %%
data = df[['FITC-A','AHL','IPTG','Family']]
#data.insert(4,'Replicate',2)
#data.to_pickle('../compiled-data/se/lux/LuxSE_2.pkl')
#uncomment these when you are ready to save replicates and compile replicate from other runs

# %%
# Subtract WT background from samples
data = df[['FITC-A','AHL','IPTG','Family']]
data['FITC-A'] = data['FITC-A'] - data[data.Family=='WT']['FITC-A'].median()
data['FITC-A'] = data[data['FITC-A'] > 0]['FITC-A']
data = data[data.Family=='LuxR']
data.drop('Family',inplace=True,axis=1)
# Out:
# <ipython-input-17-f173b810e9f9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <ipython-input-17-f173b810e9f9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data['FITC-A'].min()
# Out:
# 0.8799972534179688

# %%
data
# Out:
#              FITC-A           AHL  IPTG
# 15000   1369.279930  0.000000e+00   0.0
# 15002   1753.839989  0.000000e+00   0.0
# 15003   1820.719994  0.000000e+00   0.0
# 15004   1186.240013  0.000000e+00   0.0
# 15005   1402.719994  0.000000e+00   0.0
# ...             ...           ...   ...
# 375224  1341.120018  5.000000e-11   0.5
# 375226  1549.679955  5.000000e-11   0.5
# 375227  1008.480003  5.000000e-11   0.5
# 375234  2477.200096  5.000000e-11   0.5
# 375236  1196.799950  5.000000e-11   0.5
#
# [261547 rows x 3 columns]

# %% [markdown]
# # Plot median FITC-A

# %% [markdown]
# use median or geometeric mean

# %%
mfi = data.groupby(['AHL','IPTG'])['FITC-A'].median().reset_index()

f, ax = plt.subplots(figsize=(8,6))
sns.pointplot(x='AHL',y='FITC-A',hue='IPTG',data=mfi)
f.savefig('Lux.png',dpi=600)

# %% [markdown]
# # Plot heatmaps showing absolute and relative induction

# %% [markdown]
# Raw signal

# %%
#LasMeans = Las.groupby(['C_ahl','C_iptg']).mean().reset_index()
sns.set(style="white")
#sns.set_style('Talk')
#LasTable = pd.pivot_table(LasMeans,values='FITC-A',index='C_iptg',columns='C_ahl')
f, ax = plt.subplots(figsize=(8,6))
#g = sns.heatmap(LasTable,vmin=0,vmax=100,xticklabels=[0,1e-10,1e-9,1e-7],yticklabels=[0,1e-3,1e-4,1e-5],ax=ax,square=True,cmap='Reds')



#f.savefig('LasHeatmap.png',dpi=600)

#mean['FITC-A']=mean['FITC-A']/mean['FITC-A'].max()*100

piv = mfi.pivot_table(index='IPTG', columns='AHL', values='FITC-A')
g = sns.heatmap(piv, annot=True, fmt=".1f",cmap='Blues')
cbar = g.collections[0].colorbar
#cbar.set_ticks([0, 25, 50, 75,100])
#cbar.set_ticklabels(['0%', '25%', '50%', '75%', '100%'])
ax.set_xlabel(r'[AHL] (M)')
ax.set_ylabel(r'[IPTG] (M)')
f.tight_layout()

# %% [markdown]
# Normalized to highest signal

# %%
f, ax = plt.subplots(figsize=(8,6))
# normalized
norm = mfi.copy()
norm['FITC-A']=norm['FITC-A']/norm['FITC-A'].max()*100

piv = norm.pivot_table(index='IPTG', columns='AHL', values='FITC-A')
g = sns.heatmap(piv, annot=True, fmt=".1f",cmap='Blues')
cbar = g.collections[0].colorbar
cbar.set_ticks([0, 25, 50, 75,100])
cbar.set_ticklabels(['0%', '25%', '50%', '75%', '100%'])
ax.set_xlabel(r'[AHL] (M)')
ax.set_ylabel(r'[IPTG] (M)')
f.tight_layout()

# %% [markdown]
# # Calculate the on/off ratio and plot

# %%
R =[]
for i in mfi.IPTG.unique():
    tmp = mfi[mfi.IPTG ==i]['FITC-A'].max()/mfi[mean.IPTG ==i]['FITC-A'].min()
    R.append([i,tmp])

# %%
R = pd.DataFrame(R,columns=['IPTG','Induction Ratio'])
R
# Out:
#     IPTG  Induction Ratio
# 0  0.000         5.537778
# 1  0.001         7.901736

# %%
f, ax  = plt.subplots()
sns.barplot(x='IPTG',y='Induction Ratio',data=R,palette='Blues')

# %% [markdown]
# # Fit data to logistic function

# %%
data = mean.copy()
data.AHL[data.AHL == 0]=1e-14

# %%
data
# Out:
#              AHL   IPTG        FITC-A
# 0   1.000000e-14  0.000     87.410181
# 1   1.000000e-12  0.000   3408.650316
# 2   1.000000e-12  0.001   3526.703824
# 3   1.000000e-10  0.000   3237.155354
# 4   1.000000e-10  0.001   2333.458719
# 5   1.000000e-08  0.000   3444.413663
# 6   1.000000e-08  0.001   7966.254391
# 7   1.000000e-06  0.000   8352.352043
# 8   1.000000e-06  0.001  17842.530997
# 9   1.000000e-04  0.000   1316.996786
# 10  1.000000e-04  0.001  15699.928539

# %%
colors = ['#deebf7','#9ecae1','#3182bd']
fig, axes = plt.subplots(figsize=(6, 4))
axs = axes.ravel()
for i,iptg in enumerate(data.IPTG.unique()):
    tmp = data[data.IPTG==iptg]
    def func(x, a, b):
        return (tmp['FITC-A'].max() -tmp['FITC-A'].min()) / (1 + 10**(a * (np.log10(b)-np.log10(x)))) + tmp['FITC-A'].min()
    (a_, b_), _ = opt.curve_fit(func, tmp.AHL, tmp['FITC-A'],p0=[1,1e-9],maxfev=10000000)
    n = 1e6
    x = np.linspace(tmp.AHL.min(), tmp.AHL.max(), n)
    print(a_,b_)
    y_fit = func(x, a_, b_)

    
    ax.plot(np.log10(tmp.AHL.values), tmp['FITC-A'].values, 'o',color = colors[i])
    ax.plot(np.log10(x), y_fit, '-',color = colors[i])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-122-8aa84314dc07> in <module>
#       1 colors = ['#deebf7','#9ecae1','#3182bd']
#       2 fig, ax = plt.subplots(figsize=(6, 4))
# ----> 3 axs = axes.ravel()
#       4 for i,iptg in enumerate(data.IPTG.unique()):
#       5     tmp = data[data.IPTG==iptg]
#
# NameError: name 'axes' is not defined

# %%
tmp.AHL

# %%
#a, c = np.random.exponential(size=2,scale=1e4)
#b, d = np.random.randn(2)
a,b,c,d = 5000,1000,1e2,1e-5
n = 100
#x = np.linspace(-12, -4, n)
x = np.logspace(-12,-4,n)
y_model = f(x, a, b, c, d)
y = y_model + a * .2 * np.random.randn(n)
#(a_, b_, c_, d_), _ = opt.curve_fit(f, x, y,p0=[1e4,1,1,d])
#y_fit = f(x, a_, b_, c_, d_)

fig, ax = plt.subplots(1, 1, figsize=(6, 4))
ax.plot(x, y_model, '--k')
ax.plot(x, y, 'o')
#ax.plot(x, y_fit, '-')
plt.xscale('log')

# %%
print(a_, b_, c_, d_

# %%
# Out:
# 75632
