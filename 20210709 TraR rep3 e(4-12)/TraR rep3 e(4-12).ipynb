# %%
#%matplotlib inline
#%matplotlib notebook

# %%
import cytoflow as flow
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib
import scipy.stats as stats
import scipy as sp
from scipy.stats.mstats import gmean
import scipy.optimize as opt
import numpy as np
from numpy import median
matplotlib.rc('figure', dpi = 160)

# %% [markdown]
# # Import samples and specify experimental condtions

# %% [markdown]
# sets the conditions of the tube

# %%
inputs = [
    ["20210630 TraR_Tube_001_001.fcs",0,0,'WT'],
    
    ["20210709 TraR rep3_Tube_002_002.fcs",1e-4,0,'TraR'],
    ["20210709 TraR rep3_Tube_003_003.fcs",1e-5,0,'TraR'],
    ["20210709 TraR rep3_Tube_004_004.fcs",1e-6,0,'TraR'],
    ["20210709 TraR rep3_Tube_005_005.fcs",1e-7,0,'TraR'],
    ["20210709 TraR rep3_Tube_006_006.fcs",1e-8,0,'TraR'],
    ["20210709 TraR rep3_Tube_007_007.fcs",1e-10,0,'TraR'],
    ["20210709 TraR rep3_Tube_008_008.fcs",1e-11,0,'TraR'],
    ["20210709 TraR rep3_Tube_009_009.fcs",0,0,'TraR'],
    
    ["20210709 TraR rep3_Tube_010_010.fcs",1e-4,0.005,'TraR'],
    ["20210709 TraR rep3_Tube_011_011.fcs",1e-5,0.005,'TraR'],
    ["20210709 TraR rep3_Tube_012_012.fcs",1e-6,0.005,'TraR'],
    ["20210709 TraR rep3_Tube_013_013.fcs",1e-7,0.005,'TraR'],
    ["20210709 TraR rep3_Tube_014_014.fcs",1e-8,0.005,'TraR'],
    ["20210709 TraR rep3_Tube_015_015.fcs",1e-10,0.005,'TraR'],
    ["20210709 TraR rep3_Tube_016_016.fcs",1e-11,0.005,'TraR'],
    ["20210709 TraR rep3_Tube_017_017.fcs",0,0.005,'TraR'],
    
    ["20210709 TraR rep3_Tube_018_018.fcs",1e-4,0.01,'TraR'],
    ["20210709 TraR rep3_Tube_019_019.fcs",1e-5,0.01,'TraR'],
    ["20210709 TraR rep3_Tube_020_020.fcs",1e-6,0.01,'TraR'],
    ["20210709 TraR rep3_Tube_021_021.fcs",1e-7,0.01,'TraR'],
    ["20210709 TraR rep3_Tube_022_022.fcs",1e-8,0.01,'TraR'],
    ["20210709 TraR rep3_Tube_023_023.fcs",1e-10,0.01,'TraR'],
    ["20210709 TraR rep3_Tube_024_024.fcs",1e-11,0.01,'TraR'],
    ["20210709 TraR rep3_Tube_025_025.fcs",0,0.01,'TraR'],
    
    ["20210709 TraR rep3_Tube_026_026.fcs",1e-4,0.05,'TraR'],
    ["20210709 TraR rep3_Tube_027_027.fcs",1e-5,0.05,'TraR'],
    ["20210709 TraR rep3_Tube_028_028.fcs",1e-6,0.05,'TraR'],
    ["20210709 TraR rep3_Tube_029_029.fcs",1e-7,0.05,'TraR'],
    ["20210709 TraR rep3_Tube_030_030.fcs",1e-8,0.05,'TraR'],
    ["20210709 TraR rep3_Tube_031_031.fcs",1e-10,0.05,'TraR'],
    ["20210709 TraR rep3_Tube_032_032.fcs",1e-11,0.05,'TraR'],
    ["20210709 TraR rep3_Tube_033_033.fcs",0,0.05,'TraR'],
    
    ["20210709 TraR rep3_Tube_034_034.fcs",1e-4,0.1,'TraR'],
    ["20210709 TraR rep3_Tube_035_035.fcs",1e-5,0.1,'TraR'],
    ["20210709 TraR rep3_Tube_036_036.fcs",1e-6,0.1,'TraR'],
    ["20210709 TraR rep3_Tube_037_037.fcs",1e-7,0.1,'TraR'],
    ["20210709 TraR rep3_Tube_038_038.fcs",1e-8,0.1,'TraR'],
    ["20210709 TraR rep3_Tube_039_039.fcs",1e-10,0.1,'TraR'],
    ["20210709 TraR rep3_Tube_040_040.fcs",1e-11,0.1,'TraR'],
    ["20210709 TraR rep3_Tube_041_041.fcs",0,0.1,'TraR'],
    
    ["20210709 TraR rep3_Tube_042_042.fcs",1e-4,0.5,'TraR'],
    ["20210709 TraR rep3_Tube_043_043.fcs",1e-5,0.5,'TraR'],
    ["20210709 TraR rep3_Tube_044_044.fcs",1e-6,0.5,'TraR'],
    ["20210709 TraR rep3_Tube_045_045.fcs",1e-7,0.5,'TraR'],
    ["20210709 TraR rep3_Tube_046_046.fcs",1e-8,0.5,'TraR'],
    ["20210709 TraR rep3_Tube_047_047.fcs",1e-10,0.5,'TraR'],
    ["20210709 TraR rep3_Tube_048_048.fcs",1e-11,0.5,'TraR'],
    ["20210709 TraR rep3_Tube_049_049.fcs",0,0.5,'TraR'],

   
    


]

       
tubes = []
for filename, ahl, iptg, family in inputs:
    tubes.append(flow.Tube(file = 'data/' + filename, conditions = {'AHL' : ahl, 'IPTG' : iptg, 'Family' : family}))
    
ex = flow.ImportOp(conditions = {'AHL' : 'float', 'IPTG' : 'float', 'Family' : 'str'},
                   tubes = tubes).apply()

# %%
flow.set_default_scale("log")

# %% [markdown]
# # Plot FITC-A histograms for all IPTG and AHL induction conditions

# %%
flow.HistogramView(channel = "FITC-A",
                   xfacet = "AHL",
                  yfacet = 'IPTG').plot(ex)
# Out:
# C:\Users\Jonathan\anaconda3\envs\cf2\lib\site-packages\cytoflow\utility\log_scale.py:117: RuntimeWarning: invalid value encountered in log10

# %%
flow.DensityView(xchannel = "FSC-A", 
                 ychannel = "SSC-A",
                 xscale = 'log',
                 yscale = 'log').plot(ex, min_quantile = 0.005)

# %% [markdown]
# # Singlet gating to remove doublets

# %%
#channels = ['FSC-A','FSC-W','FSC-H','SSC-A','SSC-W','SSC-H']
#perm = combinations(channels,2)
FSC = [('FSC-A','FSC-W'),('FSC-A','FSC-H'),('FSC-W','FSC-H')]

#f, axes = plt.subplots(ncols=4,nrows=4)
#axs = axes.ravel()
for i,(x,y) in enumerate(FSC):  
    flow.DensityView(xchannel = x, 
                ychannel = y,
                xscale = 'log',
                yscale = 'log').plot(ex, min_quantile = 0.005)

# %%
SSC = [('SSC-A','SSC-W'),('SSC-A','SSC-H'),('SSC-W','SSC-H')]
for i,(x,y) in enumerate(SSC):  
    flow.DensityView(xchannel = x, 
                ychannel = y,
                xscale = 'linear',
                yscale = 'linear').plot(ex, min_quantile = 0.005)

# %% [markdown]
# ## Create and store singlet gate

# %% [markdown]
# saves the single data as ex2

# %%
r = flow.Range2DOp(name = "Range2D",
                   xchannel = "SSC-W",
                   xlow = 55000,
                   xhigh = 80000,
                   ychannel = "SSC-H",
                   ylow = 100,
                   yhigh = 10000)
                   
rv = r.default_view(xscale ='log',yscale='log')

rv.plot(ex)
ex2 = r.apply(ex)

# %% [markdown]
# ## Use a gaussian mixture model to further gate the population

# %%
gm = flow.GaussianMixtureOp(name = "GM",
                            channels = ['FSC-A', 'SSC-A'],
                            scale = {'FSC-A' : 'log',
                                     'SSC-A' : 'log'},
                            num_components = 1,
                            sigma = 2)
gm.estimate(ex2)
ex_gm = gm.apply(ex2)
gm.default_view().plot(ex_gm, alpha = 0.02)
# Out:
# C:\Users\Jonathan\anaconda3\envs\cf2\lib\site-packages\cytoflow\utility\log_scale.py:117: RuntimeWarning: invalid value encountered in log10
# C:\Users\Jonathan\anaconda3\envs\cf2\lib\site-packages\cytoflow\operations\gaussian.py:529: RuntimeWarning: invalid value encountered in less_equal
# C:\Users\Jonathan\anaconda3\envs\cf2\lib\site-packages\cytoflow\operations\base_op_views.py:342: CytoflowViewWarning: Setting 'huefacet' to 'GM_1'

# %%
gm3 = flow.GaussianMixtureOp(name = "GM3",
                            channels = ['FSC-A', 'Pacific Blue-A'],
                            scale = {'FSC-A' : 'log',
                                     'Pacific Blue-A' : 'log'},
                            num_components = 1,
                            sigma = 2)
gm3.estimate(ex_gm)
ex_gm2 = gm3.apply(ex_gm)
gm3.default_view().plot(ex_gm2, alpha = 0.02)
# Out:
# C:\Users\Jonathan\anaconda3\envs\cf2\lib\site-packages\cytoflow\utility\log_scale.py:117: RuntimeWarning: invalid value encountered in log10
# C:\Users\Jonathan\anaconda3\envs\cf2\lib\site-packages\cytoflow\operations\gaussian.py:529: RuntimeWarning: invalid value encountered in less_equal
# C:\Users\Jonathan\anaconda3\envs\cf2\lib\site-packages\cytoflow\operations\base_op_views.py:342: CytoflowViewWarning: Setting 'huefacet' to 'GM3_1'

# %%
df =ex_gm2.data

# %% [markdown]
# take the stuff from cytoflow and changing it to datatframe

# %% [markdown]
# # filter out events that don't fall within the gates

# %%
df = df[(df.GM_1==True) & (df.GM3_1==True) & (df.Range2D==True) & (df['FITC-A'] >0)]
df
# Out:
#          AHL    AmCyan-A  AmCyan-H       AmCyan-W      FITC-A  FITC-H  \
# 0        0.0  131.240005      69.0  124651.375000  125.839996   103.0
# 4        0.0   61.200001      80.0   50135.039062   73.040001   123.0
# 5        0.0   80.919998      56.0   94699.515625   67.760002    90.0
# 6        0.0   17.000000      64.0   17408.000000   73.040001    96.0
# 7        0.0  -53.040001      64.0       0.000000    8.800000    83.0
# 9        0.0   85.000000     100.0   55705.601562  126.720001    65.0
# 10       0.0   89.080002      76.0   76815.093750   47.520000    52.0
# 16       0.0   -8.840000      75.0       0.000000   31.680000    35.0
# 17       0.0   45.560001      45.0   66351.562500   43.119999   110.0
# 22       0.0  114.919998      93.0   80982.765625  106.479996   126.0
# 23       0.0   90.440002      84.0   70560.429688  114.400002    89.0
# 24       0.0   -4.760000      73.0       0.000000   51.919998    89.0
# 26       0.0   42.840000      65.0   43193.265625  126.720001   176.0
# 27       0.0   40.119999     131.0   20071.025391  102.959999   129.0
# 30       0.0   82.279999      98.0   55023.488281   87.120003   160.0
# 31       0.0  182.240005      83.0  143894.953125  126.720001    65.0
# 32       0.0   87.040001      83.0   68725.953125  110.000000   113.0
# 33       0.0   17.680000      59.0   19638.585938   24.639999    89.0
# 36       0.0   72.080002      75.0   62984.464844   46.639999    84.0
# 41       0.0   33.320000      86.0   25391.388672   54.560001   124.0
# 42       0.0   57.799999      51.0   74274.132812   65.120003    73.0
# 43       0.0   73.440002      83.0   57987.519531  111.760002    65.0
# 44       0.0  104.720001     107.0   64139.539062   77.440002   169.0
# 47       0.0   70.040001      83.0   55302.906250   76.559998   113.0
# 50       0.0   64.599998     115.0   36814.136719   22.000000    96.0
# 51       0.0   25.840000     111.0   15256.309570   74.800003    61.0
# 53       0.0   54.400002     119.0   29959.316406  152.240005    53.0
# 54       0.0   26.520000     122.0   14246.023438   97.680000    66.0
# 55       0.0  128.520004      82.0  102715.687500    8.800000    64.0
# 56       0.0  119.000000      83.0   93961.257812  220.000000   121.0
# ...      ...         ...       ...            ...         ...     ...
# 4899943  0.0   11.040000     100.0    7235.174805   39.150002    82.0
# 4899946  0.0   75.209999      94.0   52435.769531  199.229996   262.0
# 4899983  11501.400391        12065.0   62474.578125  1298.040039  1347.0
# 4899985   9007.110352         8733.0   67593.039062  1312.829956  1373.0
# 4899991   8617.349609         8243.0   68512.273438  1560.780029  1606.0
# 4899992  15007.500000        14599.0   67369.789062  2612.610107  2658.0
# 4899994  11849.400391        12267.0   63304.992188  2251.560059  2336.0
# 4899996   5720.250000         5203.0   72051.179688  1808.729980  1834.0
# 4899997   9460.379883         9603.0   64562.683594  1998.390015  2025.0
# 4899998   7582.919922         7647.0   64986.820312  1149.270020  1237.0
#
#                 SSC-W         Time  Range2D  GM_1  GM3_1
# 0        62579.210938    51.299999     True  True   True
# 4        61442.140625    51.400002     True  True   True
# 5        62792.730469    51.400002     True  True   True
# 6        67105.625000    51.400002     True  True   True
# 7        66955.828125    51.400002     True  True   True
# 9        62111.867188    51.500000     True  True   True
# 10       66356.765625    51.500000     True  True   True
# 16       66663.914062    51.900002     True  True   True
# 17       64079.648438    52.000000     True  True   True
# 22       65701.914062    52.099998     True  True   True
# 23       65694.250000    52.099998     True  True   True
# 24       77827.289062    52.099998     True  True   True
# 26       64763.640625    52.099998     True  True   True
# 27       63811.320312    52.299999     True  True   True
# 30       68805.906250    52.400002     True  True   True
# 31       68763.070312    52.400002     True  True   True
# 32       65744.539062    52.500000     True  True   True
# 33       63169.101562    52.500000     True  True   True
# 36       64269.359375    52.599998     True  True   True
# 41       63952.753906    52.799999     True  True   True
# 42       65361.242188    52.799999     True  True   True
# 43       65072.847656    52.799999     True  True   True
# 44       67129.203125    52.799999     True  True   True
# 47       66042.578125    52.900002     True  True   True
# 50       67411.453125    53.099998     True  True   True
# 51       65601.867188    53.200001     True  True   True
# 53       67599.765625    53.200001     True  True   True
# 54       64226.234375    53.200001     True  True   True
# 55       64901.007812    53.200001     True  True   True
# 56       68488.718750    53.299999     True  True   True
# ...               ...          ...      ...   ...    ...
# 4899943  62090.707031  1884.900024     True  True   True
# 4899946  66773.296875  1885.000000     True  True   True
# 4899948  64583.765625  1885.000000     True  True   True
# 4899949  66390.804688  1885.000000     True  True   True
# 4899950  66770.531250  1885.099976     True  True   True
# 4899953  66254.796875  1885.199951     True  True   True
# 4899956  65484.710938  1885.199951     True  True   True
# 4899957  65503.031250  1885.199951     True  True   True
# 4899958  68940.726562  1885.199951     True  True   True
# 4899963  68006.984375  1885.300049     True  True   True
# 4899965  62046.410156  1885.300049     True  True   True
# 4899967  64148.453125  1885.400024     True  True   True
# 4899968  63402.339844  1885.500000     True  True   True
# 4899971  64986.617188  1885.500000     True  True   True
# 4899972  72046.414062  1885.599976     True  True   True
# 4899973  63072.218750  1885.599976     True  True   True
# 4899977  61268.273438  1885.599976     True  True   True
# 4899978  62323.250000  1885.699951     True  True   True
# 4899979  65426.843750  1885.699951     True  True   True
# 4899980  64440.746094  1885.699951     True  True   True
# 4899981  64763.515625  1885.699951     True  True   True
# 4899982  65073.382812  1885.699951     True  True   True
# 4899983  63153.937500  1885.699951     True  True   True
# 4899985  62663.960938  1885.800049     True  True   True
# 4899991  63690.710938  1886.000000     True  True   True
# 4899992  64416.867188  1886.000000     True  True   True
# 4899994  63167.054688  1886.099976     True  True   True
# 4899996  64633.007812  1886.199951     True  True   True
# 4899997  64674.808594  1886.199951     True  True   True
# 4899998  60888.085938  1886.199951     True  True   True
#
# [2865821 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['AHL', 'AmCyan-A', 'AmCyan-H', 'AmCyan-W', 'FITC-A', 'FITC-H', 'FITC-W',
#        'FSC-A', 'FSC-H', 'FSC-W', 'Family', 'IPTG', 'Pacific Blue-A',
#        'Pacific Blue-H', 'Pacific Blue-W', 'PerCP-Cy5-5-A', 'PerCP-Cy5-5-H',
#        'PerCP-Cy5-5-W', 'SSC-A', 'SSC-H', 'SSC-W', 'Time', 'Range2D', 'GM_1',
#        'GM3_1'],
#       dtype='object')

# %%
data = df[['FITC-A','AHL','IPTG','Family']]
data.insert(4,'Replicate',3)
data.to_pickle('../compiled-data/se/tra/TraSE_3.pkl')
#uncomment these when you are ready to save replicates and compile replicate from other runs

# %%
# Subtract WT background from samples
data = df[['FITC-A','AHL','IPTG','Family']]
data['FITC-A'] = data['FITC-A'] - data[data.Family=='WT']['FITC-A'].median()
data['FITC-A'] = data[data['FITC-A'] > 0]['FITC-A']
data = data[data.Family=='TraR']
data.drop('Family',inplace=True,axis=1)
# Out:
# C:\Users\Jonathan\anaconda3\envs\cf2\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Jonathan\anaconda3\envs\cf2\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data['FITC-A'].min()
# Out:
# 0.8000030517578125

# %%
data
# Out:
#              FITC-A     AHL  IPTG
# 100001   256.579987  0.0001   0.0
# 100002   122.600006  0.0001   0.0
# 100004   294.860016  0.0001   0.0
# 100005   165.229996  0.0001   0.0
# 100006   133.039993  0.0001   0.0
# 100007   242.660004  0.0001   0.0
# 100009   100.850006  0.0001   0.0
# 100010   220.910004  0.0001   0.0
# 100012   147.830002  0.0001   0.0
# 100013   165.229996  0.0001   0.0
# 100014   465.379974  0.0001   0.0
# 100016   269.630005  0.0001   0.0
# 100017   402.739990  0.0001   0.0
# 100018   276.589996  0.0001   0.0
# 100019   243.529999  0.0001   0.0
# 100020   229.609985  0.0001   0.0
# 100022   327.049988  0.0001   0.0
# 100023   237.440002  0.0001   0.0
# 100024   149.570007  0.0001   0.0
# 100026    42.559998  0.0001   0.0
# 100027   240.920013  0.0001   0.0
# 100029   216.559998  0.0001   0.0
# 100030   327.920013  0.0001   0.0
# 100031   173.059998  0.0001   0.0
# 100033   158.270004  0.0001   0.0
# 100034   248.750000  0.0001   0.0
# 100035   241.790009  0.0001   0.0
# 100036   175.670013  0.0001   0.0
# 100041   266.149994  0.0001   0.0
# 100042   456.680023  0.0001   0.0
# ...             ...     ...   ...
# 4899943         NaN  0.0000   0.5
# 4899946  116.509995  0.0000   0.5
# 4899948  121.729996  0.0000   0.5
# 4899949  181.760010  0.0000   0.5
# 4899950         NaN  0.0000   0.5
# 4899953  188.720001  0.0000   0.5
# 4899956  190.459991  0.0000   0.5
# 4899957   87.800003  0.0000   0.5
# 4899958  136.520004  0.0000   0.5
# 4899963   38.209999  0.0000   0.5
# 4899965   59.089996  0.0000   0.5
# 4899967   62.569992  0.0000   0.5
# 4899968   89.539993  0.0000   0.5
# 4899971   93.020004  0.0000   0.5
# 4899972  172.190002  0.0000   0.5
# 4899973  109.550003  0.0000   0.5
# 4899977   29.510002  0.0000   0.5
# 4899978   73.009995  0.0000   0.5
# 4899979  200.899994  0.0000   0.5
# 4899980   63.440002  0.0000   0.5
# 4899981   93.889999  0.0000   0.5
# 4899982  213.950012  0.0000   0.5
# 4899983   39.949997  0.0000   0.5
# 4899985   94.759995  0.0000   0.5
# 4899991   50.389999  0.0000   0.5
# 4899992  154.789993  0.0000   0.5
# 4899994  212.209991  0.0000   0.5
# 4899996  147.830002  0.0000   0.5
# 4899997    1.669998  0.0000   0.5
# 4899998   17.330002  0.0000   0.5
#
# [2811382 rows x 3 columns]

# %% [markdown]
# # Plot median FITC-A

# %% [markdown]
# use median or geometeric mean

# %%
mfi = data.groupby(['AHL','IPTG'])['FITC-A'].median().reset_index()

f, ax = plt.subplots(figsize=(8,6))
sns.pointplot(x='AHL',y='FITC-A',hue='IPTG',data=mfi)
f.savefig('Las.png',dpi=600)

# %% [markdown]
# # Plot heatmaps showing absolute and relative induction

# %% [markdown]
# Raw signal

# %%
#LasMeans = Las.groupby(['C_ahl','C_iptg']).mean().reset_index()
sns.set(style="white")
#sns.set_style('Talk')
#LasTable = pd.pivot_table(LasMeans,values='FITC-A',index='C_iptg',columns='C_ahl')
f, ax = plt.subplots(figsize=(8,6))
#g = sns.heatmap(LasTable,vmin=0,vmax=100,xticklabels=[0,1e-10,1e-9,1e-7],yticklabels=[0,1e-3,1e-4,1e-5],ax=ax,square=True,cmap='Reds')



#f.savefig('LasHeatmap.png',dpi=600)

#mean['FITC-A']=mean['FITC-A']/mean['FITC-A'].max()*100

piv = mfi.pivot_table(index='IPTG', columns='AHL', values='FITC-A')
g = sns.heatmap(piv, annot=True, fmt=".1f",cmap='Blues')
cbar = g.collections[0].colorbar
#cbar.set_ticks([0, 25, 50, 75,100])
#cbar.set_ticklabels(['0%', '25%', '50%', '75%', '100%'])
ax.set_xlabel(r'[AHL] (M)')
ax.set_ylabel(r'[IPTG] (M)')
f.tight_layout()

# %% [markdown]
# Normalized to highest signal

# %%
f, ax = plt.subplots(figsize=(8,6))
# normalized
norm = mfi.copy()
norm['FITC-A']=norm['FITC-A']/norm['FITC-A'].max()*100

piv = norm.pivot_table(index='IPTG', columns='AHL', values='FITC-A')
g = sns.heatmap(piv, annot=True, fmt=".1f",cmap='Blues')
cbar = g.collections[0].colorbar
cbar.set_ticks([0, 25, 50, 75,100])
cbar.set_ticklabels(['0%', '25%', '50%', '75%', '100%'])
ax.set_xlabel(r'[AHL] (M)')
ax.set_ylabel(r'[IPTG] (M)')
f.tight_layout()

# %% [markdown]
# # Calculate the on/off ratio and plot

# %%
R =[]
for i in mfi.IPTG.unique():
    tmp = mfi[mfi.IPTG ==i]['FITC-A'].max()/mfi[mfi.IPTG ==i]['FITC-A'].min()
    R.append([i,tmp])

# %%
R = pd.DataFrame(R,columns=['IPTG','Induction Ratio'])
R
# Out:
#     IPTG  Induction Ratio
# 0  0.000         1.697877
# 1  0.005         1.830708
# 2  0.010         1.764357
# 3  0.050         1.882429
# 4  0.100         1.895211
# 5  0.500         1.748709

# %%
f, ax  = plt.subplots()
sns.barplot(x='IPTG',y='Induction Ratio',data=R,palette='Blues')

# %% [markdown]
# STOP HERE
