# %%
import cytoflow as flow
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib
import scipy.stats as stats
import scipy as sp
from scipy.stats.mstats import gmean
import scipy.optimize as opt
import numpy as np
from numpy import median
matplotlib.rc('figure', dpi = 160)

# %% [markdown]
# # Import samples and specify experimental condtions

# %%
#inputs = pd.read_csv('out.csv',header=None)
#inputs.columns = ['filename', 'ahl', 'iptg', 'family']
inputs =pd.read_excel('LasR updated.xls')
import os
files = list()
for x in os.listdir('data'):
    if x.endswith(".fcs"):
        files.append(x)

# %% [markdown]
# sets the conditions of the tube

# %%
       
tubes = []
for n,i in enumerate(inputs.iterrows()):
    filename =files[n]
    ahl = i[1].AHL
    iptg = i[1].IPTG
    family = i[1].Family
    tubes.append(flow.Tube(file = 'data/' + filename, conditions = {'AHL' : ahl, 'IPTG' : iptg, 'Family' : family}))
    
ex = flow.ImportOp(conditions = {'AHL' : 'float', 'IPTG' : 'float', 'Family' : 'str'},
                   tubes = tubes).apply()

# %%
flow.set_default_scale("log")

# %% [markdown]
# # Plot FITC-A histograms for all IPTG and AHL induction conditions

# %%
flow.HistogramView(channel = "FITC-A",
                   xfacet = "AHL",
                  yfacet = 'IPTG').plot(ex)
# Out:
# C:\Users\Jonathan\anaconda3\envs\cf2\lib\site-packages\cytoflow\utility\log_scale.py:117: RuntimeWarning: invalid value encountered in log10

# %%
flow.DensityView(xchannel = "FSC-A", 
                 ychannel = "SSC-A",
                 xscale = 'log',
                 yscale = 'log').plot(ex, min_quantile = 0.005)

# %% [markdown]
# # Singlet gating to remove doublets

# %%
#channels = ['FSC-A','FSC-W','FSC-H','SSC-A','SSC-W','SSC-H']
#perm = combinations(channels,2)
FSC = [('FSC-A','FSC-W'),('FSC-A','FSC-H'),('FSC-W','FSC-H')]

#f, axes = plt.subplots(ncols=4,nrows=4)
#axs = axes.ravel()
for i,(x,y) in enumerate(FSC):  
    flow.DensityView(xchannel = x, 
                ychannel = y,
                xscale = 'log',
                yscale = 'log').plot(ex, min_quantile = 0.005)

# %%
SSC = [('SSC-A','SSC-W'),('SSC-A','SSC-H'),('SSC-W','SSC-H')]
for i,(x,y) in enumerate(SSC):  
    flow.DensityView(xchannel = x, 
                ychannel = y,
                xscale = 'linear',
                yscale = 'linear').plot(ex, min_quantile = 0.005)

# %% [markdown]
# ## Create and store singlet gate

# %% [markdown]
# saves the single data as ex2

# %%
r = flow.Range2DOp(name = "Range2D",
                   xchannel = "SSC-W",
                   xlow = 55000,
                   xhigh = 80000,
                   ychannel = "SSC-H",
                   ylow = 100,
                   yhigh = 10000)
                   
rv = r.default_view(xscale ='log',yscale='log')

rv.plot(ex)
ex2 = r.apply(ex)

# %% [markdown]
# ## Use a gaussian mixture model to further gate the population

# %%
gm = flow.GaussianMixtureOp(name = "GM",
                            channels = ['FSC-A', 'SSC-A'],
                            scale = {'FSC-A' : 'log',
                                     'SSC-A' : 'log'},
                            num_components = 1,
                            sigma = 2)
gm.estimate(ex2)
ex_gm = gm.apply(ex2)
gm.default_view().plot(ex_gm, alpha = 0.02)
# Out:
# C:\Users\Jonathan\anaconda3\envs\cf2\lib\site-packages\cytoflow\utility\log_scale.py:117: RuntimeWarning: invalid value encountered in log10
# C:\Users\Jonathan\anaconda3\envs\cf2\lib\site-packages\cytoflow\operations\gaussian.py:529: RuntimeWarning: invalid value encountered in less_equal
# C:\Users\Jonathan\anaconda3\envs\cf2\lib\site-packages\cytoflow\operations\base_op_views.py:342: CytoflowViewWarning: Setting 'huefacet' to 'GM_1'

# %%
gm3 = flow.GaussianMixtureOp(name = "GM3",
                            channels = ['FSC-A', 'Pacific Blue-A'],
                            scale = {'FSC-A' : 'log',
                                     'Pacific Blue-A' : 'log'},
                            num_components = 1,
                            sigma = 2)
gm3.estimate(ex_gm)
ex_gm2 = gm3.apply(ex_gm)
gm3.default_view().plot(ex_gm2, alpha = 0.02)
# Out:
# C:\Users\Jonathan\anaconda3\envs\cf2\lib\site-packages\cytoflow\utility\log_scale.py:117: RuntimeWarning: invalid value encountered in log10
# C:\Users\Jonathan\anaconda3\envs\cf2\lib\site-packages\cytoflow\operations\gaussian.py:529: RuntimeWarning: invalid value encountered in less_equal
# C:\Users\Jonathan\anaconda3\envs\cf2\lib\site-packages\cytoflow\operations\base_op_views.py:342: CytoflowViewWarning: Setting 'huefacet' to 'GM3_1'

# %%
df =ex_gm2.data

# %% [markdown]
# take the stuff from cytoflow and changing it to datatframe

# %% [markdown]
# # filter out events that don't fall within the gates

# %%
df = df[(df.GM_1==True) & (df.GM3_1==True) & (df.Range2D==True) & (df['FITC-A'] >0)]
df
# Out:
#         AHL      FITC-A  FITC-H         FITC-W         FSC-A    FSC-H  \
# 2       0.0   50.160000    34.0   96684.882812   8884.100586   9670.0
# 4       0.0   32.560001    71.0   30054.255859  11714.310547  11390.0
# 5       0.0   80.959999    38.0  139626.187500   9093.610352   9138.0
# 12      0.0   27.280001    79.0   22630.658203  14816.080078  15131.0
# 13      0.0  104.720001   110.0   62390.277344  15267.950195  15514.0
# 15      0.0   26.400000    50.0   34603.007812  11992.440430  12102.0
# 18      0.0   26.400000    50.0   34603.007812   6751.770020   6710.0
# 20      0.0   14.960000    35.0   28011.958984  13956.870117  13559.0
# 21      0.0   74.800003    24.0  204253.875000  10870.430664  10828.0
# 22      0.0   73.040001    36.0  132965.265625   8293.530273   7728.0
# 24      0.0    5.280000    37.0    9352.163086   7597.840332   7425.0
# 29      0.0   82.720001    46.0  117850.828125   9403.860352   9370.0
# 31      0.0   82.720001    40.0  135528.453125   9686.370117   8796.0
# 32      0.0   95.919998    52.0  120888.710938  14393.410156  13264.0
# 33      0.0   22.000000    72.0   20024.888672  12272.760742  12276.0
# 34      0.0   68.639999    36.0  124955.304688   8726.419922   8864.0
# 35      0.0   29.920000    20.0   98041.851562   7525.570312   7184.0
# 37      0.0    6.160000    21.0   19223.892578   5283.740234   5153.0
# 39      0.0   69.519997    37.0  123136.820312   5944.390137   5937.0
# 40      0.0  224.399994   261.0   56345.890625  11808.480469  11457.0
# 42      0.0   54.560001    84.0   42567.195312  12227.500000  11712.0
# 43      0.0   54.560001    33.0  108352.851562   8651.230469   8293.0
# 44      0.0   87.120003    64.0   89210.882812  11665.400391  11604.0
# 47      0.0   58.959999    93.0   41548.414062   8731.530273   9097.0
# 48      0.0   55.439999    41.0   88617.453125  10378.410156  10669.0
# 50      0.0   17.600000    53.0   21762.900391   8605.240234   8353.0
# 51      0.0    5.280000    44.0    7864.319336   6850.320312   6968.0
# 55      0.0    0.880000    62.0     930.188354   6840.100098   7130.0
# 57      0.0  100.320000    91.0   72248.039062  10787.940430  10959.0
# 58      0.0   97.680000    34.0  188281.062500  13848.100586  13926.0
# ...     ...         ...     ...            ...           ...      ...
# 254933  0.0  241.119995   280.0   56435.855469   7180.280273   7420.0
# 254934  0.0   29.039999    32.0   59473.917969   6481.670410   7092.0
# 254935  0.0  234.959991   271.0   56820.433594   6682.420410   6763.0
# 254941  0.0  403.040009   329.0   80284.593750  13372.870117  13213.0
# 254942  0.0   36.959999    56.0   43253.757812   7270.800293   6956.0
# 254944  0.0  220.000000   296.0   48709.191406  12926.110352  12636.0
# 254948  0.0   21.119999    29.0   47728.285156   6830.610352   5993.0
# 254949  0.0  231.440002   256.0   59248.640625  15843.190430  15668.0
# 254951  0.0  513.919983   557.0   60467.257812   5674.290039   5881.0
# 254952  0.0  167.199997   132.0   83012.257812   7229.190430   6384.0
# 254955  0.0  253.440002   196.0   84742.062500   9462.990234   9872.0
# 254957  0.0  549.119995   581.0   61939.984375  10092.980469  10241.0
# 254958  0.0  641.520020   612.0   68697.156250  10498.129883  10832.0
# 254959  0.0  226.160004   244.0   60744.355469   9068.060547   9536.0
# 254969  0.0   26.400000    24.0   72089.601562   8259.950195   8524.0
# 254970  0.0   25.520000    16.0  104529.921875  12269.839844  11892.0
# 254971  0.0   33.439999    28.0   78268.703125   5747.290039   5976.0
# 254974  0.0  224.399994   137.0  107345.093750   7748.950195   7533.0
# 254977  0.0   60.720001    61.0   65235.179688  12417.300781  12137.0
# 254980  0.0   41.360001    32.0   84705.281250   9538.180664  10372.0
# 254981  0.0    7.920000    39.0   13308.849609  14337.200195  14819.0
# 254982  0.0  423.279999   341.0   81349.203125  14622.630859  14945.0
# 254985  0.0  692.559998   761.0   59642.066406  11826.730469  12141.0
# 254987  0.0  248.160004   276.0   58925.414062  10500.320312  11072.0
# 254988  0.0  543.840027   486.0   73335.593750  11149.290039  11938.0
# 254989  0.0  524.479980   441.0   77941.773438  13153.140625  13341.0
# 254994  0.0  324.720001   369.0   57671.683594   6096.229980   6613.0
# 254996  0.0  371.359985   413.0   58928.449219   9461.530273   9625.0
# 254997  0.0  199.759995   222.0   58970.589844  10525.870117  10554.0
# 254998  0.0  352.000000   377.0   61190.113281  12292.470703  12349.0
#
#                FSC-W Family  IPTG  Pacific Blue-A  Pacific Blue-H  \
# 2       60209.769531   #682   0.0       84.630005            57.0
# 4       67402.023438   #682   0.0       42.770000            53.0
# 5       65217.644531   #682   0.0        8.190001            25.0
# 12      64172.003906   #682   0.0       23.660000            41.0
# 13      64496.609375   #682   0.0       76.440002            48.0
# 15      64942.710938   #682   0.0       52.780003            36.0
# 18      65943.960938   #682   0.0       23.660000            36.0
# 20      67459.062500   #682   0.0       46.410000            60.0
# 21      65792.804688   #682   0.0       21.840000            52.0
# 22      70331.890625   #682   0.0       46.410000            45.0
# 24      67061.554688   #682   0.0       51.870003            49.0
# 29      65772.828125   #682   0.0       15.470000            34.0
# 31      72169.851562   #682   0.0       13.650001            46.0
# 32      71116.289062   #682   0.0       30.030001            45.0
# 33      65518.703125   #682   0.0        7.280000            40.0
# 34      64518.800781   #682   0.0       42.770000            45.0
# 35      68651.976562   #682   0.0       78.260002            57.0
# 37      67198.757812   #682   0.0       12.740001            40.0
# 39      65617.578125   #682   0.0       54.600002            57.0
# 40      67546.531250   #682   0.0       36.400002            32.0
# 42      68420.546875   #682   0.0       77.349998            45.0
# 43      68366.937500   #682   0.0       51.870003            52.0
# 44      65882.773438   #682   0.0       52.780003            35.0
# 47      62903.105469   #682   0.0       35.490002            42.0
# 48      63751.003906   #682   0.0       10.920000            44.0
# 50      67515.031250   #682   0.0       56.420002            32.0
# 51      64429.191406   #682   0.0        4.550000            57.0
# 55      62871.363281   #682   0.0       22.750000            48.0
# 57      64513.046875   #682   0.0       62.790001            69.0
# 58      65169.410156   #682   0.0       60.060001            49.0
# ...              ...    ...   ...             ...             ...
# 254933  63418.710938    mNG   0.0       25.480001            44.0
# 254934  59896.050781    mNG   0.0       16.380001            20.0
# 254935  64755.152344    mNG   0.0       45.500000            41.0
# 254941  66328.953125    mNG   0.0       15.470000            16.0
# 254942  68501.890625    mNG   0.0       45.500000            46.0
# 254944  67040.648438    mNG   0.0       83.720001            62.0
# 254948  74695.625000    mNG   0.0       31.850000            49.0
# 254949  66268.789062    mNG   0.0       60.970001            43.0
# 254951  63232.492188    mNG   0.0       39.130001            33.0
# 254952  74212.453125    mNG   0.0       23.660000            57.0
# 254955  62820.757812    mNG   0.0       83.720001            48.0
# 254957  64588.765625    mNG   0.0       52.780003            65.0
# 254958  63516.015625    mNG   0.0       24.570002            43.0
# 254959  62320.093750    mNG   0.0       26.390001            57.0
# 254969  63505.875000    mNG   0.0       58.240002            73.0
# 254970  67618.257812    mNG   0.0       19.110001            37.0
# 254971  63027.843750    mNG   0.0       86.450005            61.0
# 254974  67414.734375    mNG   0.0       36.400002            37.0
# 254977  67049.539062    mNG   0.0       10.920000            32.0
# 254980  60267.472656    mNG   0.0       30.940001            41.0
# 254981  63405.277344    mNG   0.0       17.290001            32.0
# 254982  64122.367188    mNG   0.0       41.860001            48.0
# 254985  63839.601562    mNG   0.0      107.380005            37.0
# 254987  62152.187500    mNG   0.0       17.290001            57.0
# 254988  61206.222656    mNG   0.0       10.010000            37.0
# 254989  64613.167969    mNG   0.0       43.680000            60.0
# 254994  60414.718750    mNG   0.0       38.220001            44.0
# 254996  64422.949219    mNG   0.0       10.010000            35.0
# 254997  65361.328125    mNG   0.0      183.820007            73.0
# 254998  65236.000000    mNG   0.0       70.070000            44.0
#
#         Pacific Blue-W        SSC-A   SSC-H         SSC-W         Time  \
# 2         97303.718750   778.799988   806.0  63324.363281    41.500000
# 4         52886.316406  4744.080078  4708.0  66038.242188    41.500000
# 5         21469.595703  2850.320068  2982.0  62642.042969    41.500000
# 12        37819.066406  4985.200195  5083.0  64275.046875    41.599998
# 13       104366.085938  3593.919922  3742.0  62942.582031    41.700001
# 15        96083.062500  3256.000000  3206.0  66558.078125    41.700001
# 18        43071.714844  4294.399902  4450.0  63244.449219    41.700001
# 20        50692.093750  2211.439941  2199.0  65906.742188    41.799999
# 21        27525.121094  5663.680176  5640.0  65811.164062    41.799999
# 22        67589.468750  4224.000000  4288.0  64557.851562    41.799999
# 24        69374.539062  2185.040039  2213.0  64707.992188    41.900002
# 29        29818.880859  2348.719971  2362.0  65167.531250    41.900002
# 31        19447.095703  3330.800049  3544.0  61593.488281    42.000000
# 32        43734.359375  5128.640137  4928.0  68204.265625    42.000000
# 33        11927.551758  3591.280029  3683.0  63903.917969    42.000000
# 34        62288.328125  1643.839966  1712.0  62926.816406    42.000000
# 35        89979.781250  1964.160034  1988.0  64750.097656    42.000000
# 37        20873.216797  2461.360107  2629.0  61357.050781    42.099998
# 39        62776.589844  2173.600098  2293.0  62123.445312    42.099998
# 40        74547.195312  3044.800049  3109.0  64182.699219    42.099998
# 42       112649.101562  3865.840088  3840.0  65977.007812    42.200001
# 43        65372.164062  2357.520020  2353.0  65661.890625    42.200001
# 44        98828.296875  4923.600098  5028.0  64175.234375    42.200001
# 47        55377.921875  1708.079956  1709.0  65500.718750    42.299999
# 48        16264.843750  4073.520020  4157.0  64219.921875    42.299999
# 50       115548.164062  2200.879883  2309.0  62467.242188    42.299999
# 51         5231.382324  2763.199951  2780.0  65139.953125    42.400002
# 55        31061.333984  2783.439941  2766.0  65949.210938    42.500000
# 57        59637.761719  1166.880005  1115.0  68585.335938    42.500000
# 58        80328.414062  4079.679932  4118.0  64926.160156    42.500000
# ...                ...          ...     ...           ...          ...
# 254933    37951.304688  1266.319946  1244.0  66711.843750  1168.400024
# 254934    53673.988281  1836.559937  1908.0  63082.179688  1168.699951
# 254935    72728.976562   768.239990   799.0  63012.984375  1169.099976
# 254941    63365.121094  2729.760010  2681.0  66727.914062  1170.199951
# 254942    64823.652344  1104.400024  1132.0  63938.128906  1170.300049
# 254944    88494.742188  2442.000000  2524.0  63406.859375  1170.699951
# 254948    42598.402344  1761.760010  1753.0  65863.500000  1171.599976
# 254949    92923.953125  2153.360107  2196.0  64263.488281  1171.599976
# 254951    77709.804688  1009.359985  1001.0  66083.335938  1172.000000
# 254952    27203.187500  1218.800049  1204.0  66341.593750  1172.699951
# 254955   114305.710938  1098.239990  1104.0  65194.074219  1174.800049
# 254957    53215.234375  2113.760010  2101.0  65934.015625  1175.400024
# 254958    37446.972656  1228.479980  1236.0  65137.269531  1175.500000
# 254959    30342.019531  1251.359985  1204.0  68113.890625  1175.699951
# 254969    52285.164062   763.839966   780.0  64178.226562  1178.400024
# 254970    33848.457031  4049.760010  4016.0  66086.921875  1178.599976
# 254971    92878.492188   773.520020   728.0  69633.812500  1178.599976
# 254974    64473.257812   683.760010   665.0  67384.804688  1179.099976
# 254977    22364.160156  1997.599976  2093.0  62548.832031  1179.699951
# 254980    49455.703125  2426.159912  2468.0  64424.964844  1180.599976
# 254981    35409.921875  2091.760010  2215.0  61889.656250  1181.199951
# 254982    57152.855469  1547.040039  1653.0  61335.035156  1181.400024
# 254985   190196.109375  2952.399902  2957.0  65434.054688  1181.699951
# 254987    19879.255859  2834.479980  2804.0  66248.382812  1182.000000
# 254988    17730.144531  3916.879883  3922.0  65450.445312  1182.000000
# 254989    47710.207031  2616.239990  2653.0  64627.933594  1182.099976
# 254994    56926.957031  2100.560059  2097.0  65647.257812  1182.900024
# 254996    18743.296875  1198.559937  1241.0  63294.777344  1183.199951
# 254997   165025.031250  2203.520020  2286.0  63171.429688  1183.300049
# 254998   104366.078125  3564.000000  3497.0  66791.625000  1183.500000
#
#         Range2D  GM_1  GM3_1
# 2          True  True   True
# 4          True  True   True
# 5          True  True   True
# 12         True  True   True
# 13         True  True   True
# 15         True  True   True
# 18         True  True   True
# 20         True  True   True
# 21         True  True   True
# 22         True  True   True
# 24         True  True   True
# 29         True  True   True
# 31         True  True   True
# 32         True  True   True
# 33         True  True   True
# 34         True  True   True
# 35         True  True   True
# 37         True  True   True
# 39         True  True   True
# 40         True  True   True
# 42         True  True   True
# 43         True  True   True
# 44         True  True   True
# 47         True  True   True
# 48         True  True   True
# 50         True  True   True
# 51         True  True   True
# 55         True  True   True
# 57         True  True   True
# 58         True  True   True
# ...         ...   ...    ...
# 254933     True  True   True
# 254934     True  True   True
# 254935     True  True   True
# 254941     True  True   True
# 254942     True  True   True
# 254944     True  True   True
# 254948     True  True   True
# 254949     True  True   True
# 254951     True  True   True
# 254952     True  True   True
# 254955     True  True   True
# 254957     True  True   True
# 254958     True  True   True
# 254959     True  True   True
# 254969     True  True   True
# 254970     True  True   True
# 254971     True  True   True
# 254974     True  True   True
# 254977     True  True   True
# 254980     True  True   True
# 254981     True  True   True
# 254982     True  True   True
# 254985     True  True   True
# 254987     True  True   True
# 254988     True  True   True
# 254989     True  True   True
# 254994     True  True   True
# 254996     True  True   True
# 254997     True  True   True
# 254998     True  True   True
#
# [103253 rows x 19 columns]

# %%
df.columns
# Out:
# Index(['AHL', 'FITC-A', 'FITC-H', 'FITC-W', 'FSC-A', 'FSC-H', 'FSC-W',
#        'Family', 'IPTG', 'Pacific Blue-A', 'Pacific Blue-H', 'Pacific Blue-W',
#        'SSC-A', 'SSC-H', 'SSC-W', 'Time', 'Range2D', 'GM_1', 'GM3_1'],
#       dtype='object')

# %%
import os
for x in os.listdir():
    if x.endswith(".ipynb"):
        # Prints only text file present in My Folder
        nb_name = x
        Replicate = nb_name.split('-')[1][:1]
        fam = nb_name.split('-')[0]

# %%
data = df[['FITC-A','AHL','IPTG','Family']]
data.insert(4,'Replicate',Replicate)
if fam == 'Lux':
    data.to_pickle(f'../../../../compiled-data/ec/lux/{fam}_{Replicate}.pkl')
elif fam == 'Las':
    data.to_pickle(f'../../../../compiled-data/ec/las/{fam}_{Replicate}.pkl')
if fam == 'Tra':
    data.to_pickle(f'../../../../compiled-data/ec/tra/{fam}_{Replicate}.pkl')

# %%
# Subtract WT background from samples
data = df[['FITC-A','AHL','IPTG','Family']]
data['FITC-A'] = data['FITC-A'] - data[data.Family=='#681']['FITC-A'].median()
data['FITC-A'] = data[data['FITC-A'] > 0]['FITC-A']
data = data[data.Family=='LasR']
data.drop('Family',inplace=True,axis=1)
# Out:
# C:\Users\Jonathan\anaconda3\envs\cf2\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Jonathan\anaconda3\envs\cf2\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data['FITC-A'].min()
# Out:
# 0.8799991607666016

# %%
data
# Out:
#              FITC-A       AHL  IPTG
# 10002    652.080017  0.000001   0.0
# 10003   1277.760010  0.000001   0.0
# 10012   3902.800049  0.000001   0.0
# 10013    884.400024  0.000001   0.0
# 10016    451.440002  0.000001   0.0
# 10018   1317.359985  0.000001   0.0
# 10024    504.239990  0.000001   0.0
# 10027   1367.520020  0.000001   0.0
# 10030   1464.319946  0.000001   0.0
# 10034    866.799988  0.000001   0.0
# 10035    403.919983  0.000001   0.0
# 10039    478.720001  0.000001   0.0
# 10040    891.440002  0.000001   0.0
# 10044   2228.159912  0.000001   0.0
# 10045   2011.679932  0.000001   0.0
# 10047   1657.920044  0.000001   0.0
# 10054    992.640015  0.000001   0.0
# 10056    967.119995  0.000001   0.0
# 10057    721.599976  0.000001   0.0
# 10059    668.799988  0.000001   0.0
# 10064    920.479980  0.000001   0.0
# 10068   1966.800049  0.000001   0.0
# 10069     10.560001  0.000001   0.0
# 10070   1009.359985  0.000001   0.0
# 10071    263.119995  0.000001   0.0
# 10074   1298.000000  0.000001   0.0
# 10075    313.279999  0.000001   0.0
# 10076   1070.079956  0.000001   0.0
# 10077   1589.280029  0.000001   0.0
# 10082    719.839966  0.000001   0.0
# ...             ...       ...   ...
# 249928    99.440002  0.000000   0.5
# 249930    45.760002  0.000000   0.5
# 249931   125.839996  0.000000   0.5
# 249932    98.559998  0.000000   0.5
# 249933   180.399994  0.000000   0.5
# 249936   264.000000  0.000000   0.5
# 249937    95.040001  0.000000   0.5
# 249941   132.880005  0.000000   0.5
# 249944   171.600006  0.000000   0.5
# 249947    64.239998  0.000000   0.5
# 249951   278.959991  0.000000   0.5
# 249953   369.600006  0.000000   0.5
# 249954   256.959991  0.000000   0.5
# 249955    58.080002  0.000000   0.5
# 249961    41.360001  0.000000   0.5
# 249962   498.080017  0.000000   0.5
# 249963   152.240005  0.000000   0.5
# 249964   136.399994  0.000000   0.5
# 249970    70.400002  0.000000   0.5
# 249971          NaN  0.000000   0.5
# 249974   278.079987  0.000000   0.5
# 249981   344.079987  0.000000   0.5
# 249982   167.199997  0.000000   0.5
# 249983   183.039993  0.000000   0.5
# 249986   647.679993  0.000000   0.5
# 249987   311.519989  0.000000   0.5
# 249993   198.000000  0.000000   0.5
# 249996   388.959991  0.000000   0.5
# 249997   183.919998  0.000000   0.5
# 249998   166.319992  0.000000   0.5
#
# [98531 rows x 3 columns]

# %% [markdown]
# # Plot median FITC-A

# %% [markdown]
# use median or geometeric mean

# %%
mfi = data.groupby(['AHL','IPTG'])['FITC-A'].median().reset_index()

f, ax = plt.subplots(figsize=(8,6))
sns.pointplot(x='AHL',y='FITC-A',hue='IPTG',data=mfi)
#f.savefig('LuxR.png',dpi=600)

# %% [markdown]
# # Plot heatmaps showing absolute and relative induction

# %% [markdown]
# Raw signal

# %%
sns.set(style="white")
f, ax = plt.subplots(figsize=(8,6))


piv = mfi.pivot_table(index='IPTG', columns='AHL', values='FITC-A')
g = sns.heatmap(piv, annot=True, fmt=".1f",cmap='Blues')
cbar = g.collections[0].colorbar
ax.set_xlabel(r'[AHL] (M)')
ax.set_ylabel(r'[IPTG] (M)')
f.tight_layout()

# %% [markdown]
# Normalized to highest signal

# %%
f, ax = plt.subplots(figsize=(8,6))
# normalized
norm = mfi.copy()
norm['FITC-A']=norm['FITC-A']/norm['FITC-A'].max()*100

piv = norm.pivot_table(index='IPTG', columns='AHL', values='FITC-A')
g = sns.heatmap(piv, annot=True, fmt=".1f",cmap='Blues')
cbar = g.collections[0].colorbar
cbar.set_ticks([0, 25, 50, 75,100])
cbar.set_ticklabels(['0%', '25%', '50%', '75%', '100%'])
ax.set_xlabel(r'[AHL] (M)')
ax.set_ylabel(r'[IPTG] (M)')
f.tight_layout()

# %% [markdown]
# # Calculate the on/off ratio and plot

# %%
R =[]
for i in mfi.IPTG.unique():
    tmp = mfi[mfi.IPTG ==i]['FITC-A'].max()/mfi[mfi.IPTG ==i]['FITC-A'].min()
    R.append([i,tmp])

# %%
R = pd.DataFrame(R,columns=['IPTG','Induction Ratio'])
R
# Out:
#     IPTG  Induction Ratio
# 0  0.000        37.540000
# 1  0.005        17.921052
# 2  0.010        11.098040
# 3  0.050         4.061539
# 4  0.100         4.465839
# 5  0.500         3.554404

# %%
f, ax  = plt.subplots()
sns.barplot(x='IPTG',y='Induction Ratio',data=R,palette='Blues')

# %% [markdown]
# STOP HERE
