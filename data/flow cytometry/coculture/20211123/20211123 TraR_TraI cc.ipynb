# %%
# %matplotlib inline
#%matplotlib notebook
#https://drive.google.com/drive/folders/1qAN0YS7cR978CSuFOtIhAzv9RN_wBfbT

# %%
import cytoflow as flow
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib
import scipy.stats as stats
import scipy as sp
from scipy.stats.mstats import gmean
import scipy.optimize as opt
import numpy as np
from numpy import median
matplotlib.rc('figure', dpi = 160)

# %% [markdown]
# # Import samples and specify experimental condtions

# %% [markdown]
# sets the conditions of the tube

# %%
inputs = [

    # 1,9,17  Wt:W    
    # 2,10,18 Lux:W   
    # 3,11,19 Las:W   
    # 4,12,20 Tra:W   
    # 5,13,21 LuxR:LasI
    # 6,14,22 LuxR:LuxI
    # 7,15,23 LasR:LasI
    # 8,16,24 TraR:TraI
    # 25, 29, 33 WT:682
    # 26, 30, 34 Lux:682
    # 27, 31, 35 Las:682
    # 28, 32, 36 Tra:682


    
    
    


    
    

    ["Coculture 24h_Tube"+"_004"+".fcs",'TraR','W-24','1'],
    ["Coculture 24h_Tube"+"_012"+".fcs",'TraR','W-24','2'],
    ["Coculture 24h_Tube"+"_020"+".fcs",'TraR','W-24','3'],
    
    ["Coculture 24h_Tube"+"_008"+".fcs",'TraR','TraI-24','1'],
    ["Coculture 24h_Tube"+"_016"+".fcs",'TraR','TraI-24','2'],
    ["Coculture 24h_Tube"+"_024"+".fcs",'TraR','TraI-24','3'],
    
    ["Coculture 24h_Tube"+"_028"+".fcs",'TraR','682-24','1'],
    ["Coculture 24h_Tube"+"_032"+".fcs",'TraR','682-24','2'],
    ["Coculture 24h_Tube"+"_036"+".fcs",'TraR','682-24','3'],
    
    ["Coculture 48h_Tube"+"_004"+".fcs",'TraR','W-48','1'],
    ["Coculture 48h_Tube"+"_012"+".fcs",'TraR','W-48','2'],
    ["Coculture 48h_Tube"+"_020"+".fcs",'TraR','W-48','3'],
    
    ["Coculture 48h_Tube"+"_008"+".fcs",'TraR','TraI-48','1'],
    ["Coculture 48h_Tube"+"_016"+".fcs",'TraR','TraI-48','2'],
    ["Coculture 48h_Tube"+"_024"+".fcs",'TraR','TraI-48','3'],
    
    ["Coculture 48h_Tube"+"_028"+".fcs",'TraR','682-48','1'],
    ["Coculture 48h_Tube"+"_032"+".fcs",'TraR','682-48','2'],
    ["Coculture 48h_Tube"+"_036"+".fcs",'TraR','682-48','3'],
    
    ["Coculture 24h_Tube"+"_037"+".fcs",'WT','none','1'],
   
    
    
    
    
    


]

       
tubes = []
for filename, Rprotein, Iprotein, REP in inputs:
    tubes.append(flow.Tube(file = 'data/' + filename, conditions = {'Rprotein' : Rprotein, 'Iprotein' : Iprotein, 'REP' : REP}))
    
ex = flow.ImportOp(conditions = {'Rprotein' : 'str', 'Iprotein' : 'str', 'REP' : 'float'},
                   tubes = tubes).apply()
#tubes = []
#for filename, ahl, iptg, family in inputs:
#    tubes.append(flow.Tube(file = 'data/' + filename, conditions = {'AHL' : ahl, 'IPTG' : iptg, 'Family' : family}))
#    
#ex = flow.ImportOp(conditions = {'AHL' : 'float', 'IPTG' : 'float', 'Family' : 'str'},
#                   tubes = tubes).apply()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\envs\cf2\lib\site-packages\cytoflow\operations\import_op.py in check_tube(filename, experiment, data_set)
#     470                                      meta_data_only = True,
# --> 471                                      reformat_meta = True)
#     472     except Exception as e:
#
# ~\anaconda3\envs\cf2\lib\site-packages\fcsparser\api.py in parse(path, meta_data_only, compensate, channel_naming, reformat_meta, data_set, dtype)
#     540     fcs_parser = FCSParser(path, read_data=read_data, channel_naming=channel_naming,
# --> 541                            data_set=data_set)
#     542
#
# ~\anaconda3\envs\cf2\lib\site-packages\fcsparser\api.py in __init__(self, path, read_data, channel_naming, data_set)
#     105         if path:
# --> 106             with open(path, 'rb') as f:
#     107                 self.load_file(f, data_set=data_set, read_data=read_data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/Coculture 24h_Tube_028.fcs'
#
# The above exception was the direct cause of the following exception:
#
# CytoflowError                             Traceback (most recent call last)
# <ipython-input-3-75038935648e> in <module>
#      64
#      65 ex = flow.ImportOp(conditions = {'Rprotein' : 'str', 'Iprotein' : 'str', 'REP' : 'float'},
# ---> 66                    tubes = tubes).apply()
#      67 #tubes = []
#      68 #for filename, ahl, iptg, family in inputs:
#
# ~\anaconda3\envs\cf2\lib\site-packages\cytoflow\operations\import_op.py in apply(self, experiment, metadata_only)
#     369                 tube_meta, tube_data = parse_tube(tube.file,
#     370                                                   experiment,
# --> 371                                                   data_set = self.data_set)
#     372
#     373                 if self.events:
#
# ~\anaconda3\envs\cf2\lib\site-packages\cytoflow\operations\import_op.py in parse_tube(filename, experiment, data_set, metadata_only)
#     551
#     552     if experiment:
# --> 553         check_tube(filename, experiment)
#     554         name_metadata = experiment.metadata["name_metadata"]
#     555     else:
#
# ~\anaconda3\envs\cf2\lib\site-packages\cytoflow\operations\import_op.py in check_tube(filename, experiment, data_set)
#     473         raise util.CytoflowError("FCS reader threw an error reading metadata "
#     474                                  "for tube {0}"
# --> 475                                  .format(filename)) from e
#     476
#     477     # first make sure the tube has the right channels
#
# CytoflowError: FCS reader threw an error reading metadata for tube data/Coculture 24h_Tube_028.fcs

# %%
flow.set_default_scale("log")

# %% [markdown]
# # Plot FITC-A histograms for all IPTG and AHL induction conditions

# %%
flow.HistogramView(channel = "FITC-A",
                   xfacet = 'Rprotein',
                  yfacet = 'Iprotein',
                  huefacet = 'REP').plot(ex)

# %%
flow.DensityView(xchannel = "FSC-A", 
                 ychannel = "SSC-A",
                 xscale = 'log',
                 yscale = 'log').plot(ex, min_quantile = 0.005)

# %% [markdown]
# # Singlet gating to remove doublets

# %%
#channels = ['FSC-A','FSC-W','FSC-H','SSC-A','SSC-W','SSC-H']
#perm = combinations(channels,2)
FSC = [('FSC-A','FSC-W'),('FSC-A','FSC-H'),('FSC-W','FSC-H')]

#f, axes = plt.subplots(ncols=4,nrows=4)
#axs = axes.ravel()
for i,(x,y) in enumerate(FSC):  
    flow.DensityView(xchannel = x, 
                ychannel = y,
                xscale = 'log',
                yscale = 'log').plot(ex, min_quantile = 0.005)

# %%
SSC = [('SSC-A','SSC-W'),('SSC-A','SSC-H'),('SSC-W','SSC-H')]
for i,(x,y) in enumerate(SSC):  
    flow.DensityView(xchannel = x, 
                ychannel = y,
                xscale = 'linear',
                yscale = 'linear').plot(ex, min_quantile = 0.005)

# %% [markdown]
# ## Create and store singlet gate

# %% [markdown]
# saves the single data as ex2

# %%
Chlorophyl = flow.Range2DOp(name = "Chlorophyl",
                   xchannel = "PerCP-Cy5-5-A",
                   xlow = 2000,
                   xhigh = 90000,
                   ychannel = "SSC-A",
                   ylow = 100,
                   yhigh = 15000)
                   
Chlorophylv = Chlorophyl.default_view(xscale ='log',yscale='log')

ex = Chlorophyl.apply(ex)
ex.data.groupby('Chlorophyl').size()
# Out:
# Chlorophyl
# False     103838
# True     1796162
# dtype: int64

# %%
Chlorophylv.plot(ex)

# %%
r = flow.Range2DOp(name = "Range2D",
                   xchannel = "SSC-W",
                   xlow = 55000,
                   xhigh = 80000,
                   ychannel = "SSC-H",
                   ylow = 100,
                   yhigh = 10000)
                   
rv = r.default_view(xscale ='log',yscale='log',huefacet = 'Chlorophyl')

rv.plot(ex)
ex = r.apply(ex)

# %%
ex.data.groupby('Range2D').size()
# Out:
# Range2D
# False     334611
# True     1565389
# dtype: int64

# %%
flow.DensityView(xchannel = "SSC-W", 
                 ychannel = "SSC-H",
                 xscale = 'log',
                 yscale = 'log').plot(ex, min_quantile = 0.005)

# %% [markdown]
# ## Use a gaussian mixture model to further gate the population

# %%
gm = flow.GaussianMixtureOp(name = "GM",
                            channels = ['FSC-A', 'SSC-A'],
                            scale = {'FSC-A' : 'log',
                                     'SSC-A' : 'log'},
                            num_components = 1,
                            sigma = 2)
gm.estimate(ex)
ex = gm.apply(ex)
gm.default_view().plot(ex, alpha = 0.02)
# Out:
# /opt/anaconda3/envs/flow/lib/python3.6/site-packages/cytoflow/operations/gaussian.py:529: RuntimeWarning: invalid value encountered in less_equal
# /opt/anaconda3/envs/flow/lib/python3.6/site-packages/cytoflow/operations/base_op_views.py:342: CytoflowViewWarning: Setting 'huefacet' to 'GM_1'

# %%
gm3 = flow.GaussianMixtureOp(name = "GM3",
                            channels = ['FSC-A', 'Pacific Blue-A'],
                            scale = {'FSC-A' : 'log',
                                     'Pacific Blue-A' : 'log'},
                            num_components = 1,
                            sigma = 2)
gm3.estimate(ex)
ex = gm3.apply(ex)
gm3.default_view().plot(ex, alpha = 0.02)
# Out:
# /opt/anaconda3/envs/flow/lib/python3.6/site-packages/cytoflow/operations/gaussian.py:529: RuntimeWarning: invalid value encountered in less_equal
# /opt/anaconda3/envs/flow/lib/python3.6/site-packages/cytoflow/operations/base_op_views.py:342: CytoflowViewWarning: Setting 'huefacet' to 'GM3_1'

# %%
df =ex.data

# %%
ex.data.head()
# Out:
#      AmCyan-A  AmCyan-H       AmCyan-W       FITC-A  FITC-H        FITC-W  \
# 0  157.939987     101.0  102482.718750   886.440002   938.0  61933.617188
# 1   30.739998     120.0   16788.136719  1027.059937  1036.0  64970.460938
# 2  -37.099998      92.0       0.000000   815.239990   866.0  61694.656250
# 3  133.559998     105.0   83361.789062   867.750000   725.0  78439.812500
# 4  133.559998      75.0  116706.507812   911.359985   997.0  59906.609375
#
#           FSC-A    FSC-H         FSC-W Iprotein  ...    REP  Rprotein  \
# 0   9938.940430  10078.0  64631.714844     W-24  ...    1.0      TraR
# 1  12992.919922  12936.0  65824.367188     W-24  ...    1.0      TraR
# 2  12430.520508  12406.0  65665.539062     W-24  ...    1.0      TraR
# 3   7968.320312   8161.0  63988.703125     W-24  ...    1.0      TraR
# 4  12014.640625  12273.0  64156.398438     W-24  ...    1.0      TraR
#
#          SSC-A   SSC-H         SSC-W        Time  Chlorophyl Range2D   GM_1  \
# 0   439.660004   458.0  62911.703125  577.299988        True    True   True
# 1   921.149963   972.0  62107.496094  577.400024        True    True   True
# 2  1677.650024  1713.0  64183.582031  577.400024        True    True   True
# 3   635.459961   661.0  63003.789062  577.400024        True    True   True
# 4   275.899994   309.0  58515.800781  577.400024        True    True  False
#
#    GM3_1
# 0   True
# 1   True
# 2   True
# 3  False
# 4   True
#
# [5 rows x 26 columns]

# %% [markdown]
# take the stuff from cytoflow and changing it to datatframe

# %% [markdown]
# # filter out events that don't fall within the gates

# %%
df = df[(df.GM_1==True) & (df.GM3_1==True) & (df.Range2D==True) & (df.Chlorophyl==True) & (df['FITC-A'] >0)] 
#df
#

# %%
#f, ax = plt.subplots()
#sns.kdeplot(x='SSC-W',y='SSC-H',data=df[['SSC-W', 'SSC-H']],ax=ax)

# %%
df.columns
# Out:
# Index(['AmCyan-A', 'AmCyan-H', 'AmCyan-W', 'FITC-A', 'FITC-H', 'FITC-W',
#        'FSC-A', 'FSC-H', 'FSC-W', 'Iprotein', 'Pacific Blue-A',
#        'Pacific Blue-H', 'Pacific Blue-W', 'PerCP-Cy5-5-A', 'PerCP-Cy5-5-H',
#        'PerCP-Cy5-5-W', 'REP', 'Rprotein', 'SSC-A', 'SSC-H', 'SSC-W', 'Time',
#        'Chlorophyl', 'Range2D', 'GM_1', 'GM3_1'],
#       dtype='object')

# %%
data = df[['FITC-A','Rprotein','Iprotein','REP']]
#data.insert(4,'Replicate',2)
#data.to_pickle('../compiled-data/se/lux/LuxSE_2.pkl')
#uncomment these when you are ready to save replicates and compile replicate from other runs
#data['FITC-A']
#data[data.Iprotein=='W-24']['FITC-A'].median()
#data[data.Iprotein=='W-48']['FITC-A'].median()
#data[data.Iprotein=='LuxI-48']['FITC-A']#-data[data.Iprotein=='W-48']['FITC-A'].median()

# %%
#data[data.Iprotein=='LuxI-48']['FITC-A']-data[data.Iprotein=='W-48']['FITC-A'].median()

# %%
# Subtract WT background from samples
data = df[['FITC-A','Rprotein','Iprotein','REP']]
data['FITC-A'] = data['FITC-A'] - data[data.Rprotein=='WT']['FITC-A'].median()
data['FITC-A'] = data[data['FITC-A'] > 0]['FITC-A']
#data = data[data.Family=='Lux_rep1']
#data.drop('Family',inplace=True,axis=1)
# Out:
# /opt/anaconda3/envs/flow/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda3/envs/flow/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data['FITC-A'].min()
# Out:
# 0.8900146484375

# %%
data
# Out:
#               FITC-A Rprotein Iprotein  REP
# 0         218.940002     TraR     W-24  1.0
# 1         359.559937     TraR     W-24  1.0
# 2         147.739990     TraR     W-24  1.0
# 6         119.260010     TraR     W-24  1.0
# 7         912.250000     TraR     W-24  1.0
# 8         130.830017     TraR     W-24  1.0
# 9         444.109985     TraR     W-24  1.0
# 11        635.459961     TraR     W-24  1.0
# 12        681.739990     TraR     W-24  1.0
# 13        157.529968     TraR     W-24  1.0
# 14        218.940002     TraR     W-24  1.0
# 16        139.729980     TraR     W-24  1.0
# 20        318.619995     TraR     W-24  1.0
# 21        494.839966     TraR     W-24  1.0
# 23        129.940002     TraR     W-24  1.0
# 26       1208.619995     TraR     W-24  1.0
# 27        550.020020     TraR     W-24  1.0
# 29        833.929932     TraR     W-24  1.0
# 30        453.010010     TraR     W-24  1.0
# 31        585.619995     TraR     W-24  1.0
# 33               NaN     TraR     W-24  1.0
# 34        662.160034     TraR     W-24  1.0
# 35        332.859985     TraR     W-24  1.0
# 36        373.799927     TraR     W-24  1.0
# 38        802.780029     TraR     W-24  1.0
# 39         54.289978     TraR     W-24  1.0
# 41        778.750000     TraR     W-24  1.0
# 44        204.700012     TraR     W-24  1.0
# 45        247.419983     TraR     W-24  1.0
# 47         63.190002     TraR     W-24  1.0
# ...              ...      ...      ...  ...
# 1799959   530.439941     TraR   682-48  3.0
# 1799961   371.130005     TraR   682-48  3.0
# 1799962   364.900024     TraR   682-48  3.0
# 1799967   291.919983     TraR   682-48  3.0
# 1799968   249.200012     TraR   682-48  3.0
# 1799970          NaN     TraR   682-48  3.0
# 1799973   264.329956     TraR   682-48  3.0
# 1799975   606.979980     TraR   682-48  3.0
# 1799977   778.750000     TraR   682-48  3.0
# 1799978  1114.280029     TraR   682-48  3.0
# 1799980  1412.429932     TraR   682-48  3.0
# 1799982   827.699951     TraR   682-48  3.0
# 1799983  1375.939941     TraR   682-48  3.0
# 1799986   149.519958     TraR   682-48  3.0
# 1799988          NaN     TraR   682-48  3.0
# 1799990   337.309998     TraR   682-48  3.0
# 1799991  1258.459961     TraR   682-48  3.0
# 1799993  1513.000000     TraR   682-48  3.0
# 1799994          NaN     TraR   682-48  3.0
# 1799995  1065.329956     TraR   682-48  3.0
# 1799996   422.750000     TraR   682-48  3.0
# 1799997   422.750000     TraR   682-48  3.0
# 1799998   372.020020     TraR   682-48  3.0
# 1799999          NaN     TraR   682-48  3.0
# 1802242  3759.359863       WT     none  1.0
# 1802936          NaN       WT     none  1.0
# 1805039   267.000000       WT     none  1.0
# 1851471   550.020020       WT     none  1.0
# 1865877          NaN       WT     none  1.0
# 1878390          NaN       WT     none  1.0
#
# [866267 rows x 4 columns]

# %% [markdown]
# # Plot median FITC-A

# %% [markdown]
# use median or geometeric mean

# %%
mfi = data.groupby(['Rprotein','Iprotein'])['FITC-A'].median().reset_index()
sns.set(font_scale=1.0)
f, ax = plt.subplots(figsize=(10,8))

#sns.pointplot(x='Rprotein',y='FITC-A',hue='Iprotein',data=mfi)
sns.barplot(x='Iprotein',y='FITC-A',data=mfi,order=['W-24','682-24','TraI-24','W-48','682-48','TraI-48'],ci=85)

#f.savefig('TraR*.png',dpi=600)
f.savefig('TraR_TraI_coculture.png',dpi=600, transparent=True)

# %% [markdown]
# STOP HERE
